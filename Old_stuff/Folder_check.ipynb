# %%
# Importing all needed functions
import os
import io
from contextlib import redirect_stdout
from astropy.io import fits
import glob
from Calculating_det_angles import estimate_source_angles_detectors  # Importing ma'am's function
from Tools import tools
import threading
from queue import Queue
import queue
import traceback
import pandas as pd
import os
from collections import Counter
import sys
import pandas as pd
import shutil

# %%
# reading the ttsplit file
df = pd.read_csv('ttsplit')

# getting the test and train events
test_events = df[df['category'] == 'test']['filename'].tolist()

train_events = df[df['category'] == 'train']['filename'].tolist()

# loading the event names and event types in the list

event_names = []
event_types = []

for _,row in df.iterrows():
    if (row["category"] == "test" or row["category"] == "train") and row["filename"][-1] != 'd':
        event_type,event_name = row['filename'].split("_")
        event_types.append(event_type)
        event_names.append(event_name)

print(len(event_names))
print(len(event_types))


data_set_path = r"D:\GRB_data\new_dataset"

# Get a list of all folders in the specified directory
folders = [folder for folder in os.listdir(data_set_path) if os.path.isdir(os.path.join(data_set_path, folder))]

# Create sets for faster lookup
folder_set = set(folders)
event_types = set(['GRB', 'SFLARE', 'TGF', 'SGR'])

# Count events already downloaded
downloaded_events = Counter(folder.split('_')[0] for folder in folders if folder.split('_')[0] in event_types)
print("events already downloaded\n", dict(downloaded_events))

# Create set of existing event names for faster lookup
existing_event_names = set(folder.split('_')[1] for folder in folders)

# Initialize counters for events to download
events_to_download = Counter()

# Lists to store new events
new_event_types = []
new_event_names = []

event_limit = 100000
for _, row in df.iterrows():
    event_type,event_name = row['filename'].split("_")
    if (row["category"] == "test" or row["category"] == "train") and row["filename"][-1] != 'd':
        if event_type in event_types and event_name not in existing_event_names:
            if events_to_download[event_type] < event_limit - downloaded_events[event_type]:
                events_to_download[event_type] += 1
                new_event_types.append(event_type)
                new_event_names.append(event_name)

print('events to download\n', dict(events_to_download))
# Out:
# 3492
# 3492
# events already downloaded
#  {'GRB': 1000, 'SFLARE': 1000, 'SGR': 492, 'TGF': 1000}
# events to download
#  {}

# %%
print(folders)
# Out:
# ['GRB_bn080714086', 'GRB_bn080714745', 'GRB_bn080717543', 'GRB_bn080831053', 'GRB_bn080916406', 'GRB_bn081012045', 'GRB_bn081101532', 'GRB_bn081110601', 'GRB_bn081125496', 'GRB_bn081204004', 'GRB_bn081206604', 'GRB_bn081213173', 'GRB_bn081221681', 'GRB_bn081222204', 'GRB_bn081226156', 'GRB_bn081229187', 'GRB_bn090101758', 'GRB_bn090107681', 'GRB_bn090108020', 'GRB_bn090108322', 'GRB_bn090112332', 'GRB_bn090112729', 'GRB_bn090129880', 'GRB_bn090202347', 'GRB_bn090207777', 'GRB_bn090228204', 'GRB_bn090228976', 'GRB_bn090304216', 'GRB_bn090306245', 'GRB_bn090307167', 'GRB_bn090320801', 'GRB_bn090327404', 'GRB_bn090403314', 'GRB_bn090424592', 'GRB_bn090426066', 'GRB_bn090427688', 'GRB_bn090428552', 'GRB_bn090502777', 'GRB_bn090509215', 'GRB_bn090510325', 'GRB_bn090513916', 'GRB_bn090513941', 'GRB_bn090516853', 'GRB_bn090519462', 'GRB_bn090519881', 'GRB_bn090528173', 'GRB_bn090602564', 'GRB_bn090606471', 'GRB_bn090620400', 'GRB_bn090620901', 'GRB_bn090621417', 'GRB_bn090621447', 'GRB_bn090623107', 'GRB_bn090623913', 'GRB_bn090626189', 'GRB_bn090630311', 'GRB_bn090701225', 'GRB_bn090703329', 'GRB_bn090709630', 'GRB_bn090717034', 'GRB_bn090720710', 'GRB_bn090725838', 'GRB_bn090802235', 'GRB_bn090805622', 'GRB_bn090810781', 'GRB_bn090813174', 'GRB_bn090815300', 'GRB_bn090819607', 'GRB_bn090820509', 'GRB_bn090823133', 'GRB_bn090826068', 'GRB_bn090904058', 'GRB_bn090908341', 'GRB_bn090910812', 'GRB_bn090915650', 'GRB_bn090922605', 'GRB_bn090924625', 'GRB_bn090925389', 'GRB_bn090926181', 'GRB_bn090927422', 'GRB_bn090928646', 'GRB_bn090929190', 'GRB_bn091006360', 'GRB_bn091015129', 'GRB_bn091017985', 'GRB_bn091019750', 'GRB_bn091020900', 'GRB_bn091026485', 'GRB_bn091101143', 'GRB_bn091102607', 'GRB_bn091112928', 'GRB_bn091122163', 'GRB_bn091126333', 'GRB_bn091126389', 'GRB_bn091127976', 'GRB_bn091209001', 'GRB_bn091221870', 'GRB_bn091231206', 'GRB_bn091231540', 'GRB_bn100101028', 'GRB_bn100107074', 'GRB_bn100111176', 'GRB_bn100112418', 'GRB_bn100118100', 'GRB_bn100126460', 'GRB_bn100130777', 'GRB_bn100201588', 'GRB_bn100207665', 'GRB_bn100207721', 'GRB_bn100210101', 'GRB_bn100216422', 'GRB_bn100221368', 'GRB_bn100224112', 'GRB_bn100225115', 'GRB_bn100225580', 'GRB_bn100228873', 'GRB_bn100301068', 'GRB_bn100304004', 'GRB_bn100306199', 'GRB_bn100311518', 'GRB_bn100315361', 'GRB_bn100322045', 'GRB_bn100323542', 'GRB_bn100324172', 'GRB_bn100325246', 'GRB_bn100325275', 'GRB_bn100326294', 'GRB_bn100330309', 'GRB_bn100423244', 'GRB_bn100424729', 'GRB_bn100429999', 'GRB_bn100503554', 'GRB_bn100507577', 'GRB_bn100510810', 'GRB_bn100513879', 'GRB_bn100516396', 'GRB_bn100517132', 'GRB_bn100517639', 'GRB_bn100525744', 'GRB_bn100527795', 'GRB_bn100605774', 'GRB_bn100612726', 'GRB_bn100614498', 'GRB_bn100616773', 'GRB_bn100620119', 'GRB_bn100625891', 'GRB_bn100629801', 'GRB_bn100707032', 'GRB_bn100709602', 'GRB_bn100714672', 'GRB_bn100715477', 'GRB_bn100718160', 'GRB_bn100719311', 'GRB_bn100722096', 'GRB_bn100727238', 'GRB_bn100728095', 'GRB_bn100816009', 'GRB_bn100820373', 'GRB_bn100826957', 'GRB_bn100827455', 'GRB_bn100902990', 'GRB_bn100907751', 'GRB_bn100916779', 'GRB_bn100923844', 'GRB_bn100924165', 'GRB_bn100926595', 'GRB_bn100929916', 'GRB_bn101002279', 'GRB_bn101004426', 'GRB_bn101010190', 'GRB_bn101011707', 'GRB_bn101013412', 'GRB_bn101017619', 'GRB_bn101023951', 'GRB_bn101024486', 'GRB_bn101027230', 'GRB_bn101030664', 'GRB_bn101031625', 'GRB_bn101101899', 'GRB_bn101104810', 'GRB_bn101112984', 'GRB_bn101116481', 'GRB_bn101117496', 'GRB_bn101119685', 'GRB_bn101126198', 'GRB_bn101127102', 'GRB_bn101129652', 'GRB_bn101201418', 'GRB_bn101213849', 'GRB_bn101224578', 'GRB_bn101224998', 'GRB_bn101225377', 'GRB_bn101227406', 'GRB_bn110102788', 'GRB_bn110105877', 'GRB_bn110112934', 'GRB_bn110118857', 'GRB_bn110123804', 'GRB_bn110124784', 'GRB_bn110128073', 'GRB_bn110130230', 'GRB_bn110205027', 'GRB_bn110207959', 'GRB_bn110212550', 'GRB_bn110227009', 'GRB_bn110227229', 'GRB_bn110228792', 'GRB_bn110307972', 'GRB_bn110319628', 'GRB_bn110319815', 'GRB_bn11 ...

# %%
dir_path = tools.json_path(r'data_path.json')
error_folders = []

# Function to process a single event
def process_event(folder,thread_num):
    event_type,event_name = folder.split('_')
    try:
        temp_thread = r'temp'+ str(thread_num)
        temp_path = os.path.join(dir_path, temp_thread)
        print(temp_path)
        tools.create_folder(temp_path,carefull=False)
        event = event_name
        year = '20' + event[2:4] + "/"

        # URL of the file you want to download : TRIGDAT file
        url = 'wget -q -nH --no-check-certificate --cut-dirs=7 -r -l0 -c -N -np -A "*_trigdat_*" -R "index*" -erobots=off --retr-symlinks https://heasarc.gsfc.nasa.gov/FTP/fermi/data/gbm/triggers/' + year + event + '/current/'
        tools.run_wget_download(url, temp_path)

        # Finding Trigdat file
        trig_string = "_trigdat_"
        trig_pattern = os.path.join(temp_path, 'current', f"*{trig_string}*")
        trigdat_file = glob.glob(trig_pattern)

        # Get the spacecraft pointing from here
        trigdat_filename = trigdat_file[0]

        # URL of the file you want to download : .rsp file
        url = 'wget -q -nH --no-check-certificate --cut-dirs=7 -r -l0 -c -N -np --accept-regex=".*rsp.*_n0_.*" -R "index*" -erobots=off --retr-symlinks https://heasarc.gsfc.nasa.gov/FTP/fermi/data/gbm/triggers/' + year + event + '/current/'
        tools.run_wget_download(url, temp_path)

        # Finding .rsp file
        rsp_string = ".rsp"
        rsp_pattern = os.path.join(temp_path, 'current', f"*{trig_string}*")
        rsp_file = glob.glob(trig_pattern)

        # Getting the RA and DEC
        with fits.open(rsp_file[0], memmap=True) as pha_list:
            ra_obj, dec_obj = (pha_list[0].header['RA_OBJ']), (pha_list[0].header['DEC_OBJ'])

        brightest_nai, bright_nais, brightest_bgo,nai_angles = estimate_source_angles_detectors.angle_to_grb(ra_obj, dec_obj,trigdat_filename)

        download_folder = os.path.join(data_set_path, event_type + '_' + event,'current')
        # Get a list of all files in the folder
        files = [file for file in os.listdir(download_folder)]

        # find the needed nais
        nais = []
        for nai_angle,nai in zip(nai_angles,bright_nais):
            if nai == brightest_nai or int(nai_angle) < 60: # only download the brightest detector or if the detector has anlge less than 60 deg
                nais.append(nai)
        
        # Check for correct number of nai files 1
        if len(nais) != len(files):
            error_folders.append((folder,1))
            return
        
        # check if all nais are present 2
        nai_flags = []
        for nai in nais:
            flag = False
            for file in files:
                if nai in file:
                    flag = True
                    break
            nai_flags.append(flag)
        
        if False in nai_flags:
            error_folders.append((folder,2))
            return
        
        # check if files are currupted 3
        try:
            for file in files:
                # Read data from FITS file
                with fits.open(os.path.join(download_folder,file), memmap=True) as hdul:
                    all_count_data = hdul[2].data
        except:
            error_folders.append((folder,3))
            return
        
        # error_folders.append('test')
        # Print the size of the queue
        print(folder_queue.qsize()) 

    except Exception as e:
        # Get formatted traceback
        traceback_str = traceback.format_exc()

        # Access exception attributes (example)
        if isinstance(e, ZeroDivisionError):
            error_details = "Division by zero attempted."
        else:
            error_details = str(e.args[0]) if len(e.args) else "Unknown error."

        # Custom message based on exception type
        if isinstance(e, ValueError):
            custom_message = "Invalid value provided. Check your input data."
        else:
            custom_message = "An error occurred during processing."

        # Print detailed message
        print(f"""Error:
        - Event: {event_name}
        - Exception: {type(e).__name__}
        - Message: {e}
        - Details: {error_details}
        - Traceback:
        {traceback_str}
        - {custom_message}""")

# Create a queue to store the events
folder_queue = Queue()

# Function to run the worker threads
def worker(thread_num):
    print(f"Worker thread {thread_num} started.")

    while True : #
        # Get an event from the queue
        event_name = folder_queue.get()
        print(f"Worker thread {thread_num} processing event {event_name}.")

        # Process the event
        process_event(event_name, thread_num)

        # Signal that the task is completed
        folder_queue.task_done()
        print(f"Worker thread {thread_num} processed event {event_name}.")

        if folder_queue.qsize() == 0:
            break
    
    print(f"Worker thread {thread_num} finished.")
    
# Create and start the worker threads
num_threads = 16
threads = []
for i in range(num_threads):
    worker_thread = threading.Thread(target=worker, args=(i,), daemon=True)
    worker_thread.start()
    threads.append(worker_thread)

# Add events to the queue
for folder in folders[:]:
    folder_queue.put((folder))

print(folder_queue.qsize()) 

# # Wait for all events to be processed
# folder_queue.join()
# print("All events have been processed.")

# Wait for all threads to finish
for thread in threads:
    thread.join()

print('done')

print(f'errors in \n{error_folders}')
# Out:
# Worker thread 0 started.
# Worker thread 1 started.
# Worker thread 2 started.
# Worker thread 3 started.
# Worker thread 4 started.
# Worker thread 5 started.
# Worker thread 6 started.
# Worker thread 7 started.
# Worker thread 8 started.
# Worker thread 9 started.
# Worker thread 10 started.
# Worker thread 11 started.
# Worker thread 12 started.
# Worker thread 13 started.
# Worker thread 14 started.
# Worker thread 15 started.
# 3492
# Worker thread 0 processing event GRB_bn080714086.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
# Worker thread 2 processing event GRB_bn080714745.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' already exists.
# Worker thread 6 processing event GRB_bn080717543.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' already exists.
# Worker thread 1 processing event GRB_bn080831053.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' already exists.
# Worker thread 11 processing event GRB_bn080916406.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
# Worker thread 8 processing event GRB_bn081012045.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' already exists.
# Worker thread 9 processing event GRB_bn081101532.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
# Worker thread 3 processing event GRB_bn081110601.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# Worker thread 7 processing event GRB_bn081125496.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
# Worker thread 10 processing event GRB_bn081204004.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
# Worker thread 4 processing event GRB_bn081206604.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# Worker thread 5 processing event GRB_bn081213173.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' already exists.
# Worker thread 14 processing event GRB_bn081221681.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
# Worker thread 12 processing event GRB_bn081222204.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
# Worker thread 13 processing event GRB_bn081226156.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' already exists.
# Worker thread 15 processing event GRB_bn081229187.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' created successfully.
# download start
# Downloaded bn081125496_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
# download start
# Downloaded bn081206604_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# download start
# Downloaded bn080714745_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# download start
# Downloaded bn081213173_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# download start
# Downloaded bn081222204_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
# download start
# Downloaded bn080831053_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# download start
# Downloaded bn081012045_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# download start
# Downloaded bn081221681_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
# download start
# Downloaded bn080714086_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
# download start
# Downloaded bn081226156_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# download start
# Downloaded bn080717543_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
# download start
# Downloaded bn080916406_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
# download start
# Downloaded bn081101532_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
# download start
# Downloaded bn081206604rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
#
# The brightest NaI detector is n5 - Source angle is: 26 deg
# The brightest 3 NaI detectors are n5 ( 26 deg) n4 ( 37 deg) n3 ( 41 deg)
# The brightest BGO detector is b0 ( 23 deg )
# 3476
# Worker thread 4 processed event GRB_bn081206604.
# Worker thread 4 processing event GRB_bn090101758.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' created successfully.
# download start
# Downloaded bn081125496rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
#
# The brightest NaI detector is na - Source angle is: 35 deg
# The brightest 3 NaI detectors are na ( 35 deg) nb ( 61 deg) n2 ( 75 deg)
# The brightest BGO detector is b1 ( 58 deg )
# 3475
# Worker thread 7 processed event GRB_bn081125496.
# Worker thread 7 processing event GRB_bn090107681.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' created successfully.
# download start
# Downloaded bn080831053rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# Downloaded bn081222204rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
# Downloaded bn080714745rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# Downloaded bn081213173rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# Downloaded bn081204004_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
#
# The brightest NaI detector is n1 - Source angle is: 12 deg
# The brightest 3 NaI detectors are n1 ( 12 deg) n0 ( 35 deg) n2 ( 41 deg)
# The brightest BGO detector is b0 ( 48 deg )
# download start
#
# The brightest NaI detector is n1 - Source angle is: 9 deg
# The brightest 3 NaI detectors are n1 ( 9 deg) n0 ( 25 deg) n9 ( 52 deg)
# The brightest BGO detector is b0 ( 68 deg )
#
# The brightest NaI detector is n1 - Source angle is: 9 deg
# The brightest 3 NaI detectors are n1 ( 9 deg) n0 ( 25 deg) n9 ( 53 deg)
# The brightest BGO detector is b0 ( 68 deg )
#
# The brightest NaI detector is n4 - Source angle is: 43 deg
# The brightest 3 NaI detectors are n4 ( 43 deg) n5 ( 47 deg) n3 ( 81 deg)
# The brightest BGO detector is b0 ( 45 deg )
# Downloaded bn081012045rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# Downloaded bn081221681rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
# 3474
# Worker thread 1 processed event GRB_bn080831053.
# Worker thread 1 processing event GRB_bn090108020.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# 3473
# Worker thread 12 processed event GRB_bn081222204.
# Worker thread 12 processing event GRB_bn090108322.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' already exists.
#
# The brightest NaI detector is na - Source angle is: 23 deg
# The brightest 3 NaI detectors are na ( 23 deg) n9 ( 24 deg) nb ( 53 deg)
# The brightest BGO detector is b1 ( 49 deg )
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' already exists.
# Downloaded bn080714086rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
#
# The brightest NaI detector is n2 - Source angle is: 17 deg
# The brightest 3 NaI detectors are n2 ( 17 deg) n1 ( 30 deg) n0 ( 54 deg)
# The brightest BGO detector is b0 ( 59 deg )
# 3472
# Worker thread 2 processed event GRB_bn080714745.
# Worker thread 2 processing event GRB_bn090112332.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' created successfully.
# download start
# 3471
# Worker thread 5 processed event GRB_bn081213173.
# Worker thread 5 processing event GRB_bn090112729.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' created successfully.
# download start
#
# The brightest NaI detector is n4 - Source angle is: 32 deg
# The brightest 3 NaI detectors are n4 ( 32 deg) n8 ( 41 deg) n3 ( 45 deg)
# The brightest BGO detector is b0 ( 85 deg )
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' created successfully.
# download start
# 3470
# Worker thread 8 processed event GRB_bn081012045.
# Worker thread 8 processing event GRB_bn090129880.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' created successfully.
# download start
# 3469
# Worker thread 14 processed event GRB_bn081221681.
# Worker thread 14 processing event GRB_bn090202347.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' and its contents removed successfully.
# 3468
# Worker thread 0 processed event GRB_bn080714086.
# Worker thread 0 processing event GRB_bn090207777.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' created successfully.
# download start
# Downloaded bn081226156rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
#
# The brightest NaI detector is n6 - Source angle is: 20 deg
# The brightest 3 NaI detectors are n6 ( 20 deg) n7 ( 23 deg) n3 ( 38 deg)
# The brightest BGO detector is b1 ( 82 deg )
# 3467
# Worker thread 13 processed event GRB_bn081226156.
# Worker thread 13 processing event GRB_bn090228204.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' created successfully.
# download start
# Downloaded bn081110601_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# download start
# Downloaded bn081229187_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
# download start
# Downloaded bn080717543rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
#
# The brightest NaI detector is n2 - Source angle is: 37 deg
# The brightest 3 NaI detectors are n2 ( 37 deg) na ( 59 deg) n5 ( 73 deg)
# The brightest BGO detector is b0 ( 75 deg )
# 3466
# Worker thread 6 processed event GRB_bn080717543.
# Worker thread 6 processing event GRB_bn090228976.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' created successfully.
# download start
# Downloaded bn080916406rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
#
# The brightest NaI detector is n8 - Source angle is: 21 deg
# The brightest 3 NaI detectors are n8 ( 21 deg) n7 ( 28 deg) n6 ( 50 deg)
# The brightest BGO detector is b1 ( 64 deg )
# 3465
# Worker thread 11 processed event GRB_bn080916406.
# Worker thread 11 processing event GRB_bn090304216.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' created successfully.
# download start
# Downloaded bn081101532rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
#
# The brightest NaI detector is n5 - Source angle is: 23 deg
# The brightest 3 NaI detectors are n5 ( 23 deg) n2 ( 46 deg) n1 ( 69 deg)
# The brightest BGO detector is b0 ( 25 deg )
# 3464
# Worker thread 9 processed event GRB_bn081101532.
# Worker thread 9 processing event GRB_bn090306245.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' created successfully.
# download start
# Downloaded bn081204004rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
#
# The brightest NaI detector is n1 - Source angle is: 29 deg
# The brightest 3 NaI detectors are n1 ( 29 deg) n0 ( 32 deg) n9 ( 34 deg)
# The brightest BGO detector is b0 ( 87 deg )
# 3463
# Worker thread 10 processed event GRB_bn081204004.
# Worker thread 10 processing event GRB_bn090307167.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' created successfully.
# download start
# Downloaded bn081110601rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
#
# The brightest NaI detector is n8 - Source angle is: 23 deg
# The brightest 3 NaI detectors are n8 ( 23 deg) n7 ( 24 deg) nb ( 46 deg)
# The brightest BGO detector is b1 ( 49 deg )
# 3462
# Worker thread 3 processed event GRB_bn081110601.
# Worker thread 3 processing event GRB_bn090320801.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' created successfully.
# download start
# Downloaded bn081229187rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
#
# The brightest NaI detector is n3 - Source angle is: 20 deg
# The brightest 3 NaI detectors are n3 ( 20 deg) n4 ( 43 deg) n6 ( 44 deg)
# The brightest BGO detector is b0 ( 76 deg )
# 3461
# Worker thread 15 processed event GRB_bn081229187.
# Worker thread 15 processing event GRB_bn090327404.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' created successfully.
# download start
# Downloaded bn090101758_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# download start
# Downloaded bn090107681_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
# download start
# Downloaded bn090112332_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# download start
# Downloaded bn090108322_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
# download start
# Downloaded bn090129880_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# download start
# Downloaded bn090112729_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# download start
# Downloaded bn090228204_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# download start
# Downloaded bn090228976_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
# download start
# Downloaded bn090108020_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# download start
# Downloaded bn090101758rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
#
# The brightest NaI detector is na - Source angle is: 8 deg
# The brightest 3 NaI detectors are na ( 8 deg) n9 ( 52 deg) n2 ( 59 deg)
# The brightest BGO detector is b1 ( 63 deg )
# Downloaded bn090112332rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
#
# The brightest NaI detector is n0 - Source angle is: 7 deg
# The brightest 3 NaI detectors are n0 ( 7 deg) n1 ( 31 deg) n6 ( 35 deg)
# The brightest BGO detector is b0 ( 83 deg )
# 3460
# Worker thread 4 processed event GRB_bn090101758.
# Worker thread 4 processing event GRB_bn090403314.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' created successfully.
# download start
# 3459
# Worker thread 2 processed event GRB_bn090112332.
# Worker thread 2 processing event GRB_bn090424592.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' created successfully.
# download start
# Downloaded bn090306245_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
# download start
# Downloaded bn090107681rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
#
# The brightest NaI detector is nb - Source angle is: 55 deg
# The brightest 3 NaI detectors are nb ( 55 deg) n8 ( 65 deg) na ( 79 deg)
# The brightest BGO detector is b1 ( 56 deg )
# 3458
# Worker thread 7 processed event GRB_bn090107681.
# Worker thread 7 processing event GRB_bn090426066.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' created successfully.
# download start
# Downloaded bn090307167_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
# download start
# Downloaded bn090129880rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# Downloaded bn090108322rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
#
# The brightest NaI detector is n1 - Source angle is: 24 deg
# The brightest 3 NaI detectors are n1 ( 24 deg) n2 ( 32 deg) n0 ( 42 deg)
# The brightest BGO detector is b0 ( 73 deg )
#
# The brightest NaI detector is n3 - Source angle is: 20 deg
# The brightest 3 NaI detectors are n3 ( 20 deg) n6 ( 31 deg) n0 ( 33 deg)
# The brightest BGO detector is b0 ( 73 deg )
# Downloaded bn090112729rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# Downloaded bn090304216_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
# download start
#
# The brightest NaI detector is na - Source angle is: 11 deg
# The brightest 3 NaI detectors are na ( 11 deg) n9 ( 57 deg) n2 ( 60 deg)
# The brightest BGO detector is b1 ( 62 deg )
# 3457
# Worker thread 12 processed event GRB_bn090108322.
# Worker thread 12 processing event GRB_bn090427688.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' already exists.
# 3456
# Worker thread 8 processed event GRB_bn090129880.
# Worker thread 8 processing event GRB_bn090428552.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' created successfully.
# download start
# 3455
# Worker thread 5 processed event GRB_bn090112729.
# Worker thread 5 processing event GRB_bn090502777.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' created successfully.
# download start
# Downloaded bn090228204rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
#
# The brightest NaI detector is n0 - Source angle is: 4 deg
# The brightest 3 NaI detectors are n0 ( 4 deg) n1 ( 20 deg) n6 ( 45 deg)
# The brightest BGO detector is b0 ( 74 deg )
# 3454Downloaded bn090207777_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
#
# Worker thread 13 processed event GRB_bn090228204.
# Worker thread 13 processing event GRB_bn090509215.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' created successfully.
# download start
# Downloaded bn090320801_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# download start
# Downloaded bn090228976rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
#
# The brightest NaI detector is n9 - Source angle is: 30 deg
# The brightest 3 NaI detectors are n9 ( 30 deg) n6 ( 35 deg) n1 ( 38 deg)
# The brightest BGO detector is b1 ( 85 deg )
# Downloaded bn090108020rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
#
# The brightest NaI detector is n1 - Source angle is: 15 deg
# The brightest 3 NaI detectors are n1 ( 15 deg) n2 ( 32 deg) n0 ( 39 deg)
# The brightest BGO detector is b0 ( 53 deg )
# 3453
# Worker thread 6 processed event GRB_bn090228976.
# Worker thread 6 processing event GRB_bn090510325.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' created successfully.
# download start
# 3452
# Worker thread 1 processed event GRB_bn090108020.
# Worker thread 1 processing event GRB_bn090513916.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' created successfully.
# download start
# Downloaded bn090306245rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
#
# The brightest NaI detector is n0 - Source angle is: 24 deg
# The brightest 3 NaI detectors are n0 ( 24 deg) n6 ( 26 deg) n3 ( 30 deg)
# The brightest BGO detector is b0 ( 79 deg )
# Downloaded bn090202347_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
# download start
# 3451
# Worker thread 9 processed event GRB_bn090306245.
# Worker thread 9 processing event GRB_bn090513941.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' created successfully.
# download start
# Downloaded bn090307167rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
#
# The brightest NaI detector is nb - Source angle is: 31 deg
# The brightest 3 NaI detectors are nb ( 31 deg) na ( 32 deg) n9 ( 38 deg)
# The brightest BGO detector is b1 ( 28 deg )
# 3450
# Worker thread 10 processed event GRB_bn090307167.
# Worker thread 10 processing event GRB_bn090516853.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' created successfully.
# download start
# Downloaded bn090304216rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
#
# The brightest NaI detector is n7 - Source angle is: 11 deg
# The brightest 3 NaI detectors are n7 ( 11 deg) n6 ( 20 deg) n9 ( 50 deg)
# The brightest BGO detector is b1 ( 57 deg )
# 3449
# Worker thread 11 processed event GRB_bn090304216.
# Worker thread 11 processing event GRB_bn090519462.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' created successfully.
# download start
# Downloaded bn090320801rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
#
# The brightest NaI detector is na - Source angle is: 19 deg
# The brightest 3 NaI detectors are na ( 19 deg) nb ( 42 deg) n9 ( 50 deg)
# The brightest BGO detector is b1 ( 38 deg )
# Downloaded bn090207777rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
#
# The brightest NaI detector is n9 - Source angle is: 24 deg
# The brightest 3 NaI detectors are n9 ( 24 deg) n0 ( 36 deg) n1 ( 39 deg)
# The brightest BGO detector is b1 ( 82 deg )
# 3448
# Worker thread 3 processed event GRB_bn090320801.
# Worker thread 3 processing event GRB_bn090519881.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' created successfully.
# download start
# 3447
# Worker thread 0 processed event GRB_bn090207777.
# Worker thread 0 processing event GRB_bn090528173.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' created successfully.
# download start
# Downloaded bn090327404_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
# download start
# Downloaded bn090202347rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
#
# The brightest NaI detector is n1 - Source angle is: 13 deg
# The brightest 3 NaI detectors are n1 ( 13 deg) n0 ( 21 deg) n9 ( 48 deg)
# The brightest BGO detector is b0 ( 73 deg )
# 3446
# Worker thread 14 processed event GRB_bn090202347.
# Worker thread 14 processing event GRB_bn090602564.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' created successfully.
# download start
# Downloaded bn090327404rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
#
# The brightest NaI detector is n1 - Source angle is: 18 deg
# The brightest 3 NaI detectors are n1 ( 18 deg) n2 ( 30 deg) n0 ( 40 deg)
# The brightest BGO detector is b0 ( 62 deg )
# 3445
# Worker thread 15 processed event GRB_bn090327404.
# Worker thread 15 processing event GRB_bn090606471.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' created successfully.
# download start
# Downloaded bn090403314_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# download start
# Downloaded bn090428552_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# download start
# Downloaded bn090502777_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# download start
# Downloaded bn090509215_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# download start
# Downloaded bn090510325_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
# download start
# Downloaded bn090513916_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# download start
# Downloaded bn090424592_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# download start
# Downloaded bn090403314rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
#
# The brightest NaI detector is n7 - Source angle is: 15 deg
# The brightest 3 NaI detectors are n7 ( 15 deg) n6 ( 27 deg) n8 ( 46 deg)
# The brightest BGO detector is b1 ( 73 deg )
# 3444
# Worker thread 4 processed event GRB_bn090403314.
# Worker thread 4 processing event GRB_bn090620400.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' created successfully.
# download start
# Downloaded bn090513941_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
# download start
# Downloaded bn090427688_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
# download start
# Downloaded bn090426066_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
# download start
# Downloaded bn090428552rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
#
# The brightest NaI detector is n5 - Source angle is: 31 deg
# The brightest 3 NaI detectors are n5 ( 31 deg) n4 ( 32 deg) n3 ( 57 deg)
# The brightest BGO detector is b0 ( 28 deg )
# Downloaded bn090502777rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# Downloaded bn090519881_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# 3443
# Worker thread 8 processed event GRB_bn090428552.
# Worker thread 8 processing event GRB_bn090620901.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' already exists.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' created successfully.
# download start
#
# The brightest NaI detector is n8 - Source angle is: 13 deg
# The brightest 3 NaI detectors are n8 ( 13 deg) n7 ( 33 deg) nb ( 49 deg)
# The brightest BGO detector is b1 ( 52 deg )
# 3442
# Worker thread 5 processed event GRB_bn090502777.
# Worker thread 5 processing event GRB_bn090621417.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' already exists.
# Downloaded bn090519462_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' created successfully.
# download start
# Downloaded bn090509215rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
#
# The brightest NaI detector is nb - Source angle is: 17 deg
# The brightest 3 NaI detectors are nb ( 17 deg) n7 ( 42 deg) n8 ( 50 deg)
# The brightest BGO detector is b1 ( 18 deg )
# Downloaded bn090528173_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
# download start
# 3441
# Worker thread 13 processed event GRB_bn090509215.
# Worker thread 13 processing event GRB_bn090621447.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' created successfully.
# download start
# Downloaded bn090510325rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
#
# The brightest NaI detector is nb - Source angle is: 50 deg
# The brightest 3 NaI detectors are nb ( 50 deg) na ( 54 deg) n8 ( 82 deg)
# The brightest BGO detector is b1 ( 49 deg )
# 3440
# Worker thread 6 processed event GRB_bn090510325.
# Worker thread 6 processing event GRB_bn090623107.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' created successfully.
# download start
# Downloaded bn090513916rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
#
# The brightest NaI detector is nb - Source angle is: 66 deg
# The brightest 3 NaI detectors are nb ( 66 deg) n8 ( 69 deg) na ( 85 deg)
# The brightest BGO detector is b1 ( 67 deg )
# Downloaded bn090424592rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
#
# The brightest NaI detector is n7 - Source angle is: 19 deg
# The brightest 3 NaI detectors are n7 ( 19 deg) n8 ( 29 deg) n6 ( 44 deg)
# The brightest BGO detector is b1 ( 48 deg )
# 3439
# Worker thread 1 processed event GRB_bn090513916.
# Worker thread 1 processing event GRB_bn090623913.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' created successfully.
# download start
# 3438
# Worker thread 2 processed event GRB_bn090424592.
# Worker thread 2 processing event GRB_bn090626189.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' created successfully.
# download start
# Downloaded bn090427688rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
#
# The brightest NaI detector is n2 - Source angle is: 14 deg
# The brightest 3 NaI detectors are n2 ( 14 deg) n1 ( 46 deg) na ( 53 deg)
# The brightest BGO detector is b0 ( 71 deg )
# Downloaded bn090513941rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
#
# The brightest NaI detector is n5 - Source angle is: 55 deg
# The brightest 3 NaI detectors are n5 ( 55 deg) n2 ( 68 deg) n4 ( 76 deg)
# The brightest BGO detector is b0 ( 56 deg )
# 3437
# Worker thread 9 processed event GRB_bn090513941.
# Worker thread 9 processing event GRB_bn090630311.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp9' created successfully.
# download start
# 3436
# Worker thread 12 processed event GRB_bn090427688.
# Worker thread 12 processing event GRB_bn090701225.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp12' created successfully.
# download start
# Downloaded bn090426066rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
#
# The brightest NaI detector is n3 - Source angle is: 18 deg
# The brightest 3 NaI detectors are n3 ( 18 deg) n5 ( 44 deg) n4 ( 46 deg)
# The brightest BGO detector is b0 ( 42 deg )
# 3435
# Worker thread 7 processed event GRB_bn090426066.
# Worker thread 7 processing event GRB_bn090703329.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' created successfully.
# download start
# Downloaded bn090519881rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
#
# The brightest NaI detector is n1 - Source angle is: 24 deg
# The brightest 3 NaI detectors are n1 ( 24 deg) n0 ( 29 deg) n9 ( 39 deg)
# The brightest BGO detector is b0 ( 82 deg )
# Downloaded bn090516853_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
# download start
# 3434
# Worker thread 3 processed event GRB_bn090519881.
# Worker thread 3 processing event GRB_bn090709630.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' created successfully.
# download start
# Downloaded bn090519462rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
#
# The brightest NaI detector is n6 - Source angle is: 12 deg
# The brightest 3 NaI detectors are n6 ( 12 deg) n0 ( 34 deg) n7 ( 35 deg)
# The brightest BGO detector is b1 ( 87 deg )
# 3433
# Worker thread 11 processed event GRB_bn090519462.
# Worker thread 11 processing event GRB_bn090717034.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' created successfully.
# download start
# Downloaded bn090528173rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
#
# The brightest NaI detector is na - Source angle is: 29 deg
# The brightest 3 NaI detectors are na ( 29 deg) n2 ( 37 deg) n9 ( 57 deg)
# The brightest BGO detector is b1 ( 85 deg )
# 3432
# Worker thread 0 processed event GRB_bn090528173.
# Worker thread 0 processing event GRB_bn090720710.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' created successfully.
# download start
# Downloaded bn090516853rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
#
# The brightest NaI detector is n4 - Source angle is: 20 deg
# The brightest 3 NaI detectors are n4 ( 20 deg) n3 ( 26 deg) n5 ( 59 deg)
# The brightest BGO detector is b0 ( 56 deg )
# 3431
# Worker thread 10 processed event GRB_bn090516853.
# Worker thread 10 processing event GRB_bn090725838.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp10' created successfully.
# download start
# Downloaded bn090602564_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
# download start
# Downloaded bn090606471_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
# download start
# Downloaded bn090602564rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
#
# The brightest NaI detector is na - Source angle is: 62 deg
# The brightest 3 NaI detectors are na ( 62 deg) n8 ( 72 deg) n9 ( 96 deg)
# The brightest BGO detector is b1 ( 46 deg )
# 3430
# Worker thread 14 processed event GRB_bn090602564.
# Worker thread 14 processing event GRB_bn090802235.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' created successfully.
# download start
# Downloaded bn090620400_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# download start
# Downloaded bn090606471rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
#
# The brightest NaI detector is na - Source angle is: 59 deg
# The brightest 3 NaI detectors are na ( 59 deg) n2 ( 63 deg) nb ( 88 deg)
# The brightest BGO detector is b1 ( 86 deg )
# 3429
# Worker thread 15 processed event GRB_bn090606471.
# Worker thread 15 processing event GRB_bn090805622.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' created successfully.
# download start
# Downloaded bn090620901_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# download start
# Downloaded bn090621417_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# download start
# Downloaded bn090621447_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# download start
# Downloaded bn090623107_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
# download start
# Downloaded bn090623913_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# download start
# Downloaded bn090620400rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# Downloaded bn090701225_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
# download start
#
# The brightest NaI detector is n7 - Source angle is: 11 deg
# The brightest 3 NaI detectors are n7 ( 11 deg) n6 ( 35 deg) n8 ( 40 deg)
# The brightest BGO detector is b1 ( 49 deg )
# 3428
# Worker thread 4 processed event GRB_bn090620400.
# Worker thread 4 processing event GRB_bn090810781.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' created successfully.
# download start
# Downloaded bn090709630_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# download start
# Downloaded bn090626189_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# download start
# Downloaded bn090720710_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
# download start
# Downloaded bn090620901rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# Downloaded bn090621417rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
#
# The brightest NaI detector is n9 - Source angle is: 27 deg
# The brightest 3 NaI detectors are n9 ( 27 deg) n7 ( 36 deg) nb ( 46 deg)
# The brightest BGO detector is b0 ( 135 deg )
#
# The brightest NaI detector is nb - Source angle is: 19 deg
# The brightest 3 NaI detectors are nb ( 19 deg) n9 ( 43 deg) na ( 50 deg)
# The brightest BGO detector is b1 ( 17 deg )
# Downloaded bn090717034_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
# Downloaded bn090621447rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# download start
# 3427
# Worker thread 5 processed event GRB_bn090621417.
# Worker thread 5 processing event GRB_bn090813174.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
#
# The brightest NaI detector is n8 - Source angle is: 28 deg
# The brightest 3 NaI detectors are n8 ( 28 deg) n4 ( 39 deg) n7 ( 52 deg)
# The brightest BGO detector is b1 ( 84 deg )
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' and its contents removed successfully.
# 3426
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' created successfully.
# download start
# Worker thread 8 processed event GRB_bn090620901.
# Worker thread 8 processing event GRB_bn090815300.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' created successfully.
# download start
# 3425
# Worker thread 13 processed event GRB_bn090621447.
# Worker thread 13 processing event GRB_bn090819607.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' created successfully.
# download start
# Downloaded bn090630311_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
# download start
# Downloaded bn090703329_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
# download start
# Downloaded bn090623107rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
#
# The brightest NaI detector is nb - Source angle is: 25 deg
# The brightest 3 NaI detectors are nb ( 25 deg) n7 ( 32 deg) n8 ( 42 deg)
# The brightest BGO detector is b1 ( 27 deg )
# 3424
# Worker thread 6 processed event GRB_bn090623107.
# Worker thread 6 processing event GRB_bn090820509.
# ...
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp0' created successfully.
# download start
# 12
# Worker thread 15 processed event TGF_bn231012486.
# Worker thread 15 processing event TGF_bn240101635.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp15' created successfully.
# download start
# Downloaded bn231106972_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# download start
# Downloaded bn231018389_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
# download start
# Downloaded bn231106972rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
#
# The brightest NaI detector is n4 - Source angle is: 21 deg
# The brightest 3 NaI detectors are n4 ( 21 deg) n3 ( 29 deg) n8 ( 61 deg)
# The brightest BGO detector is b0 ( 66 deg )
# 11
# Worker thread 4 processed event TGF_bn231106972.
# Worker thread 4 processing event TGF_bn240104661.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp4' created successfully.
# download start
# Downloaded bn231014399rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
#
# The brightest NaI detector is n0 - Source angle is: 12 deg
# The brightest 3 NaI detectors are n0 ( 12 deg) n6 ( 34 deg) n9 ( 39 deg)
# The brightest BGO detector is b0 ( 87 deg )
# 10
# Worker thread 6 processed event TGF_bn231014399.
# Worker thread 6 processing event TGF_bn240106572.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp6' created successfully.
# download start
# Downloaded bn231018389rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
#
# The brightest NaI detector is n3 - Source angle is: 24 deg
# The brightest 3 NaI detectors are n3 ( 24 deg) n4 ( 33 deg) n7 ( 53 deg)
# The brightest BGO detector is b0 ( 73 deg )
# 9
# Worker thread 11 processed event TGF_bn231018389.
# Worker thread 11 processing event TGF_bn240111862.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp11' created successfully.
# download start
# Downloaded bn231106425_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
# download start
# Downloaded bn231022627_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# download start
# Downloaded bn231130359_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
# download start
# Downloaded bn231106425rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
#
# The brightest NaI detector is n3 - Source angle is: 36 deg
# The brightest 3 NaI detectors are n3 ( 36 deg) n7 ( 40 deg) n4 ( 42 deg)
# The brightest BGO detector is b0 ( 87 deg )
# 8
# Worker thread 7 processed event TGF_bn231106425.
# Worker thread 7 processing event TGF_bn240131678.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp7' created successfully.
# download start
# Downloaded bn231022627rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
#
# The brightest NaI detector is n8 - Source angle is: 68 deg
# The brightest 3 NaI detectors are n8 ( 68 deg) n4 ( 71 deg) nb ( 86 deg)
# The brightest BGO detector is b1 ( 87 deg )
# 7
# Worker thread 8 processed event TGF_bn231022627.
# Worker thread 8 processing event TGF_bn240210490.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp8' created successfully.
# download start
# Downloaded bn231029583rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
#
# The brightest NaI detector is n2 - Source angle is: 26 deg
# The brightest 3 NaI detectors are n2 ( 26 deg) na ( 43 deg) n1 ( 47 deg)
# The brightest BGO detector is b0 ( 82 deg )
# 6
# Worker thread 13 processed event TGF_bn231029583.
# Worker thread 13 processing event TGF_bn240303255.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp13' created successfully.
# download start
# Downloaded bn231124834_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# download start
# Downloaded bn231208267_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# download start
# Downloaded bn231111430_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# download start
# Downloaded bn231108264_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# download start
# Downloaded bn231130359rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
#
# The brightest NaI detector is n2 - Source angle is: 51 deg
# The brightest 3 NaI detectors are n2 ( 51 deg) n5 ( 67 deg) na ( 77 deg)
# The brightest BGO detector is b0 ( 68 deg )
# 5
# Worker thread 14 processed event TGF_bn231130359.
# Worker thread 14 processing event TGF_bn240307606.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp14' created successfully.
# download start
# Downloaded bn231204648_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
# download start
# Downloaded bn231220343_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
# download start
# Downloaded bn231124834rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
#
# The brightest NaI detector is n0 - Source angle is: 16 deg
# The brightest 3 NaI detectors are n0 ( 16 deg) n3 ( 34 deg) n6 ( 37 deg)
# The brightest BGO detector is b0 ( 70 deg )
# Downloaded bn231222461_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
# download start
# 4
# Worker thread 1 processed event TGF_bn231124834.
# Worker thread 1 processing event TGF_bn240310563.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp1' created successfully.
# download start
# Downloaded bn231111430rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# Downloaded bn231208267rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
#
# The brightest NaI detector is nb - Source angle is: 25 deg
# The brightest 3 NaI detectors are nb ( 25 deg) n8 ( 29 deg) n7 ( 41 deg)
# The brightest BGO detector is b1 ( 28 deg )
#
# The brightest NaI detector is n8 - Source angle is: 5 deg
# The brightest 3 NaI detectors are n8 ( 5 deg) n7 ( 41 deg) nb ( 54 deg)
# The brightest BGO detector is b1 ( 58 deg )
# Downloaded bn231108264rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# 3
# Worker thread 3 processed event TGF_bn231111430.
# Worker thread 3 processing event TGF_bn240312136.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' already exists.
# 2
# Worker thread 5 processed event TGF_bn231208267.
# Worker thread 5 processing event TGF_bn240313903.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' already exists.
#
# The brightest NaI detector is n4 - Source angle is: 12 deg
# The brightest 3 NaI detectors are n4 ( 12 deg) n3 ( 44 deg) n5 ( 49 deg)
# The brightest BGO detector is b0 ( 45 deg )
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp3' created successfully.
# download start
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp5' created successfully.
# download start
# 1
# Worker thread 2 processed event TGF_bn231108264.
# Worker thread 2 processing event TGF_bn240325600.
# C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' already exists.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' and its contents removed successfully.
# Folder 'C:\Users\arpan\OneDrive\Documents\GRB\data\temp2' created successfully.
# download start
# Downloaded bn240101635_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
# download start
# Downloaded bn231113416_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
# download start
# Downloaded bn231204648rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp12
#
# The brightest NaI detector is n3 - Source angle is: 11 deg
# The brightest 3 NaI detectors are n3 ( 11 deg) n6 ( 48 deg) n1 ( 50 deg)
# The brightest BGO detector is b0 ( 57 deg )
# 0
# Worker thread 12 processed event TGF_bn231204648.
# Worker thread 12 finished.
# Downloaded bn231220343rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp10
#
# The brightest NaI detector is na - Source angle is: 31 deg
# The brightest 3 NaI detectors are na ( 31 deg) nb ( 36 deg) n9 ( 61 deg)
# The brightest BGO detector is b1 ( 32 deg )
# 0
# Worker thread 10 processed event TGF_bn231220343.
# Worker thread 10 finished.
# Downloaded bn240104661_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
# download start
# Downloaded bn231222461rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp0
#
# The brightest NaI detector is n9 - Source angle is: 28 deg
# The brightest 3 NaI detectors are n9 ( 28 deg) n0 ( 30 deg) n1 ( 33 deg)
# The brightest BGO detector is b1 ( 87 deg )
# Downloaded bn240106572_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
# download start
# 0
# Worker thread 0 processed event TGF_bn231222461.
# Worker thread 0 finished.
# Downloaded bn240111862_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
# download start
# Downloaded bn240101635rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp15
#
# The brightest NaI detector is n4 - Source angle is: 75 deg
# The brightest 3 NaI detectors are n4 ( 75 deg) n5 ( 84 deg) nb ( 96 deg)
# The brightest BGO detector is b0 ( 83 deg )
# 0
# Worker thread 15 processed event TGF_bn240101635.
# Worker thread 15 finished.
# Downloaded bn231113416rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp9
#
# The brightest NaI detector is n4 - Source angle is: 62 deg
# The brightest 3 NaI detectors are n4 ( 62 deg) n2 ( 63 deg) n3 ( 85 deg)
# The brightest BGO detector is b0 ( 30 deg )
# 0
# Worker thread 9 processed event TGF_bn231113416.
# Worker thread 9 finished.
# Downloaded bn240104661rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp4
#
# The brightest NaI detector is n2 - Source angle is: 6 deg
# The brightest 3 NaI detectors are n2 ( 6 deg) n1 ( 42 deg) n5 ( 58 deg)
# The brightest BGO detector is b0 ( 61 deg )
# 0
# Worker thread 4 processed event TGF_bn240104661.
# Worker thread 4 finished.
# Downloaded bn240106572rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp6
#
# The brightest NaI detector is n0 - Source angle is: 15 deg
# The brightest 3 NaI detectors are n0 ( 15 deg) n6 ( 28 deg) n3 ( 39 deg)
# The brightest BGO detector is b0 ( 80 deg )
# 0
# Worker thread 6 processed event TGF_bn240106572.
# Worker thread 6 finished.
# Downloaded bn240111862rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp11
#
# The brightest NaI detector is n5 - Source angle is: 28 deg
# The brightest 3 NaI detectors are n5 ( 28 deg) n3 ( 36 deg) n4 ( 39 deg)
# The brightest BGO detector is b0 ( 26 deg )
# 0
# Worker thread 11 processed event TGF_bn240111862.
# Worker thread 11 finished.
# Downloaded bn240131678_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
# download start
# Downloaded bn240210490_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
# download start
# Downloaded bn240303255_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
# download start
# Downloaded bn240307606_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
# download start
# Downloaded bn240131678rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp7
#
# The brightest NaI detector is n2 - Source angle is: 75 deg
# The brightest 3 NaI detectors are n2 ( 75 deg) na ( 88 deg) n4 ( 91 deg)
# The brightest BGO detector is b0 ( 78 deg )
# 0
# Worker thread 7 processed event TGF_bn240131678.
# Worker thread 7 finished.
# Downloaded bn240210490rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp8
#
# The brightest NaI detector is n8 - Source angle is: 26 deg
# The brightest 3 NaI detectors are n8 ( 26 deg) n4 ( 62 deg) nb ( 63 deg)
# The brightest BGO detector is b1 ( 67 deg )
# 0
# Worker thread 8 processed event TGF_bn240210490.
# Worker thread 8 finished.
# Downloaded bn240325600_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
# download start
# Downloaded bn240310563_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
# download start
# Downloaded bn240312136_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
# download start
# Downloaded bn240313903_trigdat_ to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
# download start
# Downloaded bn240303255rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp13
#
# The brightest NaI detector is nb - Source angle is: 11 deg
# The brightest 3 NaI detectors are nb ( 11 deg) n8 ( 42 deg) n7 ( 51 deg)
# The brightest BGO detector is b1 ( 15 deg )
# 0
# Worker thread 13 processed event TGF_bn240303255.
# Worker thread 13 finished.
# Downloaded bn240307606rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp14
#
# The brightest NaI detector is nb - Source angle is: 20 deg
# The brightest 3 NaI detectors are nb ( 20 deg) n8 ( 37 deg) n7 ( 40 deg)
# The brightest BGO detector is b1 ( 23 deg )
# 0
# Worker thread 14 processed event TGF_bn240307606.
# Worker thread 14 finished.
# Downloaded bn240325600rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp2
#
# The brightest NaI detector is na - Source angle is: 70 deg
# The brightest 3 NaI detectors are na ( 70 deg) nb ( 77 deg) n2 ( 85 deg)
# The brightest BGO detector is b1 ( 76 deg )
# 0
# Worker thread 2 processed event TGF_bn240325600.
# Worker thread 2 finished.
# Downloaded bn240310563rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp1
#
# The brightest NaI detector is n0 - Source angle is: 20 deg
# The brightest 3 NaI detectors are n0 ( 20 deg) n6 ( 22 deg) n9 ( 41 deg)
# The brightest BGO detector is b1 ( 88 deg )
# 0
# Worker thread 1 processed event TGF_bn240310563.
# Worker thread 1 finished.
# Downloaded bn240312136rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp3
#
# The brightest NaI detector is nb - Source angle is: 13 deg
# The brightest 3 NaI detectors are nb ( 13 deg) na ( 48 deg) n9 ( 59 deg)
# The brightest BGO detector is b1 ( 9 deg )
# 0
# Worker thread 3 processed event TGF_bn240312136.
# Worker thread 3 finished.
# Downloaded bn240313903rsp. to C:\Users\arpan\OneDrive\Documents\GRB\data\temp5
#
# The brightest NaI detector is n6 - Source angle is: 20 deg
# The brightest 3 NaI detectors are n6 ( 20 deg) n0 ( 22 deg) n3 ( 40 deg)
# The brightest BGO detector is b0 ( 88 deg )
# 0
# Worker thread 5 processed event TGF_bn240313903.
# Worker thread 5 finished.
# done
# errors in
# []

# %%
print(len(error_folders))
print(error_folders)

# # delete error folders
# for folder in error_folders:
#     folder = os.path.join(data_set_path,folder[0])
#     shutil.rmtree(folder)
# Out:
# 0
# []
