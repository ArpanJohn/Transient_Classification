# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        pass
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import json

def find_json_file(directory):
    """
    Find a JSON file in a directory (and its subdirectories) and load it into a dictionary.
    
    Parameters:
        directory (str): Path to the directory to search.
    
    Returns:
        dict or None: Dictionary containing the JSON data if a file is found, 
                      None otherwise.
    """
    for root, dirs, files in os.walk(directory):
        for file_name in files:
            if file_name.endswith('.json'):
                file_path = os.path.join(root, file_name)
                with open(file_path, 'r') as file:
                    try:
                        json_data = json.load(file)
                        return json_data
                    except json.JSONDecodeError:
                        print(f"Error: JSON decode failed for file '{file_path}'")
    print("No JSON file found in the directory.")
    return None

# # Example usage:
# directory_path = '/path/to/directory'  # Replace with the path to your directory
# json_data = find_json_file(directory_path)
# if json_data:
#     print(json_data)

# %%
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import json
# importing data
# Read the 2D array back from the text file
dir_path = r"/kaggle/input/dp04-04-1/dp04-04-1"          #dp1-1set/dp1-1
event_types = {1:'GRB',2:'TGF',3:'SGR',4:'SFLARE'}
event_counter = {'GRB':0,'TGF':0,'SGR':0,'SFLARE':0}
# Replace 'your_search_string' with the string you are looking for in file names
search_string = 'bn'
search_pattern = os.path.join(dir_path, f'*{search_string}*')
matching_files = glob.glob(search_pattern)
json_data = find_json_file(dir_path)
print(json_data)
# Out:
# {'bin list': [0.001, 0.005, 0.01, 0.1, 0.5, 1, 5], 'time interval': [-10, 50], 'number of data points': 78792, 'data set name': 'dp03-04-1', 'data set path': 'C:\\Users\\arpan\\OneDrive\\Documents\\GRB\\data\\dp03-04-1'}

# %%
X_dict1 = {str(key): [] for key in json_data['bin list']}
t = json_data['time interval'][1]-json_data['time interval'][0]
print(t)
print(X_dict1)

Y = []

for file in matching_files:
    event_type , event_name = file.split('/')[-1].split('_')
    loaded_data = np.loadtxt(file, delimiter='\t').astype(np.int32)
    
    if event_type not in event_counter.keys():
        continue

    y = [0,0,0,0]
    
    for key,value in event_types.items():
        if value in file.split('\\')[-1]:
            y[key-1] = 1
            Y.append(y)
            event_counter[value] += 1
            sgrf = 1 if key == 3 else 0
            if sgrf == 1:
                Y.append(y)
                event_counter[value] += 1
            break
    
    f = 0
    for k in X_dict1.keys():
        X_dict1[k].append(loaded_data[f:f+int(t/float(k))])
        f = f + int(t/float(k))
    if sgrf == 1:
        f = 0
        for k in X_dict1.keys():
            X_dict1[k].append(loaded_data[f:f+int(t/float(k))])
            f = f + int(t/float(k))
        
skip_keys = []#['0.001','0.005']
X_dict={}
for k in X_dict1.keys():
    if k in skip_keys:
        continue
    X_dict[k] = np.array(X_dict1[k])
    X_dict1[k] = np.array(X_dict1[k])
    X_dict[k] = np.reshape(X_dict1[k],X_dict1[k].shape+tuple([1]))
    print(type(X_dict[k]))
    print(X_dict[k].shape)
Y = np.array(Y)
print(Y.shape)
print(event_counter)
# Out:
# 60
# {'0.001': [], '0.005': [], '0.01': [], '0.1': [], '0.5': [], '1': [], '5': []}
# <class 'numpy.ndarray'>
# (4825, 60000, 1)
# <class 'numpy.ndarray'>
# (4825, 12000, 1)
# <class 'numpy.ndarray'>
# (4825, 6000, 1)
# <class 'numpy.ndarray'>
# (4825, 600, 1)
# <class 'numpy.ndarray'>
# (4825, 120, 1)
# <class 'numpy.ndarray'>
# (4825, 60, 1)
# <class 'numpy.ndarray'>
# (4825, 5, 1)
# (4825, 4)
# {'GRB': 1649, 'TGF': 1139, 'SGR': 978, 'SFLARE': 1059}

# %%
print(event_counter)

import random

num = random.randint(1, 100)
# Split the train and the validation set for the fitting
from sklearn.model_selection import train_test_split

X_train = {str(key): [] for key in X_dict.keys()}
X_test = {str(key): [] for key in  X_dict.keys()}
Y_train = {str(key): [] for key in X_dict.keys()}
Y_test = {str(key): [] for key in  X_dict.keys()}

for k in X_train.keys():
    X_train[k], X_test[k], Y_train[k], Y_test[k] = train_test_split(X_dict[k], Y, test_size = 0.2, random_state=num)
    
    print("X_train shape",k,np.array(X_train[k]).shape)
    print("X_test shape",k, np.array(X_test[k]).shape)
    print("Y_train shape",  np.array(Y_train[k]).shape)
    print("Y_test shape",   np.array(Y_test[k]).shape)

import numpy as np

def check_same_2d_arrays(dictionary):
    arrays = list(dictionary.values())
    for i in range(1, len(arrays)):
        if not np.array_equal(arrays[i], arrays[0]):
            return False
    return True
print(check_same_2d_arrays(Y_train))
print(check_same_2d_arrays(Y_test))

Y_train = np.array(Y_train[list([k for k in Y_train.keys()])[0]])
Y_test = np.array(Y_test[list([k for k in Y_test.keys()])[0]])

print(Y_train.shape)
print(Y_test.shape)
# Out:
# {'GRB': 1649, 'TGF': 1139, 'SGR': 978, 'SFLARE': 1059}
# X_train shape 0.001 (3860, 60000, 1)
# X_test shape 0.001 (965, 60000, 1)
# Y_train shape (3860, 4)
# Y_test shape (965, 4)
# X_train shape 0.005 (3860, 12000, 1)
# X_test shape 0.005 (965, 12000, 1)
# Y_train shape (3860, 4)
# Y_test shape (965, 4)
# X_train shape 0.01 (3860, 6000, 1)
# X_test shape 0.01 (965, 6000, 1)
# Y_train shape (3860, 4)
# Y_test shape (965, 4)
# X_train shape 0.1 (3860, 600, 1)
# X_test shape 0.1 (965, 600, 1)
# Y_train shape (3860, 4)
# Y_test shape (965, 4)
# X_train shape 0.5 (3860, 120, 1)
# X_test shape 0.5 (965, 120, 1)
# Y_train shape (3860, 4)
# Y_test shape (965, 4)
# X_train shape 1 (3860, 60, 1)
# X_test shape 1 (965, 60, 1)
# Y_train shape (3860, 4)
# Y_test shape (965, 4)
# X_train shape 5 (3860, 5, 1)
# X_test shape 5 (965, 5, 1)
# Y_train shape (3860, 4)
# Y_test shape (965, 4)
# True
# True
# (3860, 4)
# (965, 4)

# %%
# # Apply SMOTE for oversampling
# from imblearn.over_sampling import SMOTE

# smote = SMOTE()
# X_train_resampled, Y_train_resampled = smote.fit_resample(np.concatenate(list(X_train.values()), axis=1), Y_train)

# # Split the oversampled data back into the original dictionary format
# X_train_resampled = dict(zip(X_train.keys(), np.array_split(X_train_resampled, len(X_train), axis=0)))
# Y_train_resampled = dict(zip(Y_train.keys(), np.array_split(Y_train_resampled, len(Y_train), axis=0)))

# print(X_train_resampled)
# print(Y_train_resampled)

# %%
from keras.models import Model
from keras.layers import Dense, concatenate,Input, Conv1D,BatchNormalization,Flatten,Dropout, Reshape, Conv2D, MaxPooling1D
import math

def create_input_layers(data_dict):
    """
    Create input layers and Conv1D layers based on the number of entries in the dictionary and the shape of the lists in the dictionary.
    
    Parameters:
        data_dict (dict): Dictionary containing dataset names as keys and dataset lists as values.
    
    Returns:
        list: List of input layers.
        list: List of Conv1D layers.
    """
    input_layers = []
    conv_layers = []
    layer_count = 0
    for dataset_name, dataset_list in data_dict.items():
        
        input_shape = tuple([len(dataset_list[0]),1])  # Assuming all lists have the same length
        
        input_layer = Input(shape=input_shape, name=str(dataset_name))
        
        norm = BatchNormalization()(input_layer)  # Add a BatchNormalization layer after each input layer
        
        filter_size = 64
        kernel_size = 32    
        if input_shape[0] < 4:
            filter_size = 2
            kernel_size = 1
        elif input_shape[0] < 8:
            filter_size = 4
            kernel_size = 2
        elif input_shape[0] < 16:
            filter_size = 8
            kernel_size = 4
        elif input_shape[0] < 32:
            filter_size = 16
            kernel_size = 8
        elif input_shape[0] < 64:
            filter_size = 32
            kernel_size = 16

        
        s = norm.shape[1]
        m = (math.floor(np.log10(abs(s))+1))
        d = 0.1 * (m*2-3 )
        stride = m*2-3
        if stride < 1:
            stride = 1
        if d < 0:
            d = 0.1
        print('name',dataset_name)
        print('m', m)
        print('dropout',d)
        print('strides',stride)
        
        conv1 = Conv1D(filters = filter_size, kernel_size = kernel_size,strides = stride, activation='selu')(norm)  # Add a Conv1D layer after the Dropout layer
        
        dropout1 = Dropout(d)(conv1)
        
        flat = Flatten()(dropout1)
        
        dense = Dense(64, activation = 'mish')(flat) 
        
        d2 = Dropout(0.75)(dense)
        
        input_layers.append(input_layer)
        
        conv_layers.append(d2)
        
        layer_count = layer_count + 1
        
    return input_layers, conv_layers, layer_count

def build_model(data_dict):
    """
    Build a Keras model using input layers based on the number of entries in the dictionary and the shape of the lists in the dictionary.
    
    Parameters:
        data_dict (dict): Dictionary containing dataset names as keys and dataset lists as values.
    
    Returns:
        keras.models.Model: Keras model.
    """
    input_layers, conv_layers, layer_count = create_input_layers(data_dict)
    
    # Concatenate Conv1D layers
    merged = concatenate(conv_layers, axis = -1)
    
    reshaped = Reshape((len(data_dict), 64, 1))(merged)
    
    # Conv2D layer
    conv2d = Conv2D(64, (layer_count, layer_count ), activation='selu')(reshaped)

    # Flatten
    flattened = Flatten()(conv2d)
    
    # Dropout
    drop = Dropout(0.75)(flattened)
    
    # Add dense layers
    output = Dense(4, activation='softmax')(drop)  # Example output layer
    
    # Create the model
    model = Model(inputs=input_layers, outputs=output)
    
    return model

# Build the model
model = build_model(X_train)

# Print model summary
model.summary()

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# name 0.001
# m 5
# dropout 0.7000000000000001
# strides 7
# name 0.005
# m 5
# dropout 0.7000000000000001
# strides 7
# name 0.01
# m 4
# dropout 0.5
# strides 5
# name 0.1
# m 3
# dropout 0.30000000000000004
# strides 3
# name 0.5
# m 3
# dropout 0.30000000000000004
# strides 3
# name 1
# m 2
# dropout 0.1
# strides 1
# name 5
# m 1
# dropout 0.1
# strides 1
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ 0.001 (InputLayer)  │ (None, 60000, 1)  │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 0.005 (InputLayer)  │ (None, 12000, 1)  │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 0.01 (InputLayer)   │ (None, 6000, 1)   │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 0.1 (InputLayer)    │ (None, 600, 1)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 0.5 (InputLayer)    │ (None, 120, 1)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 1 (InputLayer)      │ (None, 60, 1)     │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 5 (InputLayer)      │ (None, 5, 1)      │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60000, 1)  │          4 │ 0.001[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12000, 1)  │          4 │ 0.005[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6000, 1)   │          4 │ 0.01[0][0]        │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 600, 1)    │          4 │ 0.1[0][0]         │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 1)    │          4 │ 0.5[0][0]         │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 1)     │          4 │ 1[0][0]           │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 1)      │          4 │ 5[0][0]           │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_22 (Conv1D)  │ (None, 8567, 64)  │      2,112 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_23 (Conv1D)  │ (None, 1710, 64)  │      2,112 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_24 (Conv1D)  │ (None, 1194, 64)  │      2,112 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_25 (Conv1D)  │ (None, 190, 64)   │      2,112 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_26 (Conv1D)  │ (None, 30, 64)    │      2,112 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_27 (Conv1D)  │ (None, 45, 32)    │        544 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_28 (Conv1D)  │ (None, 4, 4)      │         12 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_46          │ (None, 8567, 64)  │          0 │ conv1d_22[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_48          │ (None, 1710, 64)  │          0 │ conv1d_23[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_50          │ (None, 1194, 64)  │          0 │ conv1d_24[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_52          │ (None, 190, 64)   │          0 │ conv1d_25[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_54          │ (None, 30, 64)    │          0 │ conv1d_26[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_56          │ (None, 45, 32)    │          0 │ conv1d_27[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_58          │ (None, 4, 4)      │          0 │ conv1d_28[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_24          │ (None, 548288)    │          0 │ dropout_46[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_25          │ (None, 109440)    │          0 │ dropout_48[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_26          │ (None, 76416)     │          0 │ dropout_50[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_27          │ (None, 12160)     │          0 │ dropout_52[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_28          │ (None, 1920)      │          0 │ dropout_54[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_29          │ (None, 1440)      │          0 │ dropout_56[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_30          │ (None, 16)        │          0 │ dropout_58[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 64)        │ 35,090,496 │ flatten_24[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_25 (Dense)    │ (None, 64)        │  7,004,224 │ flatten_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_26 (Dense)    │ (None, 64)        │  4,890,688 │ flatten_26[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_27 (Dense)    │ (None, 64)        │    778,304 │ flatten_27[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_28 (Dense)    │ (None, 64)        │    122,944 │ flatten_28[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_29 (Dense)    │ (None, 64)        │     92,224 │ flatten_29[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 64)        │      1,088 │ flatten_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_47          │ (None, 64)        │          0 │ dense_24[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_49          │ (None, 64)        │          0 │ dense_25[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_51          │ (None, 64)        │          0 │ dense_26[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_53          │ (None, 64)        │          0 │ dense_27[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_55          │ (None, 64)        │          0 │ dense_28[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_57          │ (None, 64)        │          0 │ dense_29[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_59          │ (None, 64)        │          0 │ dense_30[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 448)       │          0 │ dropout_47[0][0], │
# │ (Concatenate)       │                   │            │ dropout_49[0][0], │
# │                     │                   │            │ dropout_51[0][0], │
# │                     │                   │            │ dropout_53[0][0], │
# │                     │                   │            │ dropout_55[0][0], │
# │                     │                   │            │ dropout_57[0][0], │
# │                     │                   │            │ dropout_59[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 7, 64, 1)  │          0 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 1, 58, 64) │      3,200 │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_31          │ (None, 3712)      │          0 │ conv2d_3[0][0]    │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_60          │ (None, 3712)      │          0 │ flatten_31[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 4)         │     14,852 │ dropout_60[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 48,009,164 (183.14 MB)
#  Trainable params: 48,009,150 (183.14 MB)
#  Non-trainable params: 14 (56.00 B)

# %%
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import Callback

class CustomEarlyStopping(Callback):
    def __init__(self, threshold=0.85, patience=2):
        super(CustomEarlyStopping, self).__init__()
        self.threshold = threshold
        self.patience = patience
        self.wait = 0

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get('accuracy')
        if current is None:
            return

        if current >= self.threshold:
            self.wait += 1
            if self.wait >= self.patience:
                self.model.stop_training = True
        else:
            self.wait = 0

custom_early_stopping = CustomEarlyStopping()

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=2000)

# Train the model
history = model.fit(X_train, Y_train, epochs=3500, batch_size=128, validation_split=0.3, callbacks=[custom_early_stopping,early_stopping])
# Out:
# Epoch 1/3500
# W0000 00:00:1712311348.553367     193 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1712311348.554589     193 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3393 - loss: 2.1911
# W0000 00:00:1712311378.816166     191 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1712311378.817010     191 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.3409 - loss: 2.1741 - val_accuracy: 0.2332 - val_loss: 15.3527
# Epoch 2/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.4515 - loss: 1.3479 - val_accuracy: 0.2349 - val_loss: 2.4828
# Epoch 3/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.4631 - loss: 1.2538 - val_accuracy: 0.3497 - val_loss: 1.2899
# Epoch 4/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.5046 - loss: 1.1012 - val_accuracy: 0.3713 - val_loss: 1.1614
# Epoch 5/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.4967 - loss: 1.0833 - val_accuracy: 0.5216 - val_loss: 1.1034
# Epoch 6/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.5085 - loss: 1.0755 - val_accuracy: 0.5570 - val_loss: 1.0520
# Epoch 7/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.5468 - loss: 1.0121 - val_accuracy: 0.3066 - val_loss: 1.2213
# Epoch 8/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.5181 - loss: 1.1397 - val_accuracy: 0.5674 - val_loss: 1.0021
# Epoch 9/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.5326 - loss: 1.0403 - val_accuracy: 0.5397 - val_loss: 1.0496
# Epoch 10/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.5590 - loss: 1.0194 - val_accuracy: 0.5691 - val_loss: 0.9618
# Epoch 11/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.5913 - loss: 0.9414 - val_accuracy: 0.6157 - val_loss: 0.9394
# Epoch 12/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6000 - loss: 0.9570 - val_accuracy: 0.6762 - val_loss: 0.9605
# Epoch 13/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.5712 - loss: 0.9832 - val_accuracy: 0.6149 - val_loss: 0.9312
# Epoch 14/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6173 - loss: 0.9092 - val_accuracy: 0.5855 - val_loss: 0.9290
# Epoch 15/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.5971 - loss: 0.9093 - val_accuracy: 0.6252 - val_loss: 0.9110
# Epoch 16/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.5794 - loss: 0.9941 - val_accuracy: 0.5794 - val_loss: 0.9337
# Epoch 17/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.6124 - loss: 0.9721 - val_accuracy: 0.7029 - val_loss: 0.9166
# Epoch 18/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6092 - loss: 0.9530 - val_accuracy: 0.7280 - val_loss: 0.9016
# Epoch 19/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6338 - loss: 0.8586 - val_accuracy: 0.7375 - val_loss: 0.8980
# Epoch 20/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6465 - loss: 0.8460 - val_accuracy: 0.7720 - val_loss: 0.8526
# Epoch 21/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6402 - loss: 0.9224 - val_accuracy: 0.7444 - val_loss: 0.8485
# Epoch 22/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6393 - loss: 0.8792 - val_accuracy: 0.7668 - val_loss: 0.8322
# Epoch 23/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6652 - loss: 0.8103 - val_accuracy: 0.7470 - val_loss: 0.8462
# Epoch 24/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.6551 - loss: 0.8068 - val_accuracy: 0.7755 - val_loss: 0.8270
# Epoch 25/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.6752 - loss: 0.7877 - val_accuracy: 0.7617 - val_loss: 1.0105
# Epoch 26/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.6953 - loss: 0.8145 - val_accuracy: 0.6580 - val_loss: 0.9085
# Epoch 27/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.6677 - loss: 1.1435 - val_accuracy: 0.7988 - val_loss: 0.9953
# Epoch 28/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6856 - loss: 0.8402 - val_accuracy: 0.7383 - val_loss: 0.9483
# Epoch 29/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6999 - loss: 0.8128 - val_accuracy: 0.7936 - val_loss: 0.8673
# Epoch 30/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6912 - loss: 0.7994 - val_accuracy: 0.8221 - val_loss: 0.8195
# Epoch 31/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7178 - loss: 0.7454 - val_accuracy: 0.7642 - val_loss: 0.7546
# Epoch 32/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7283 - loss: 0.7023 - val_accuracy: 0.7660 - val_loss: 0.8780
# Epoch 33/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7380 - loss: 0.6510 - val_accuracy: 0.8178 - val_loss: 0.8138
# Epoch 34/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7551 - loss: 0.6743 - val_accuracy: 0.7841 - val_loss: 0.8039
# Epoch 35/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7380 - loss: 0.7687 - val_accuracy: 0.7893 - val_loss: 0.7971
# Epoch 36/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7334 - loss: 0.8462 - val_accuracy: 0.7997 - val_loss: 0.7647
# Epoch 37/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7388 - loss: 0.7259 - val_accuracy: 0.7047 - val_loss: 0.7371
# Epoch 38/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7235 - loss: 0.7623 - val_accuracy: 0.7651 - val_loss: 0.7779
# Epoch 39/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7314 - loss: 0.8800 - val_accuracy: 0.7668 - val_loss: 0.8382
# Epoch 40/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6121 - loss: 1.0662 - val_accuracy: 0.7824 - val_loss: 0.8826
# Epoch 41/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6209 - loss: 1.0901 - val_accuracy: 0.6831 - val_loss: 0.9069
# Epoch 42/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.5955 - loss: 1.1241 - val_accuracy: 0.8109 - val_loss: 0.8222
# Epoch 43/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6524 - loss: 0.8993 - val_accuracy: 0.7789 - val_loss: 0.8058
# Epoch 44/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6810 - loss: 0.8151 - val_accuracy: 0.7807 - val_loss: 0.8086
# Epoch 45/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6856 - loss: 0.7872 - val_accuracy: 0.7807 - val_loss: 0.8401
# Epoch 46/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6619 - loss: 0.8492 - val_accuracy: 0.7962 - val_loss: 0.7889
# Epoch 47/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6602 - loss: 0.8150 - val_accuracy: 0.8057 - val_loss: 0.7957
# Epoch 48/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6983 - loss: 0.8219 - val_accuracy: 0.8066 - val_loss: 0.7870
# Epoch 49/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6938 - loss: 0.7818 - val_accuracy: 0.8187 - val_loss: 0.8811
# Epoch 50/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.7065 - loss: 1.0771 - val_accuracy: 0.8230 - val_loss: 0.7873
# Epoch 51/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7144 - loss: 0.7828 - val_accuracy: 0.8238 - val_loss: 0.7964
# Epoch 52/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7031 - loss: 0.7664 - val_accuracy: 0.7781 - val_loss: 0.7697
# Epoch 53/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6816 - loss: 0.9186 - val_accuracy: 0.7962 - val_loss: 0.8435
# Epoch 54/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6708 - loss: 1.1367 - val_accuracy: 0.7945 - val_loss: 0.8958
# Epoch 55/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6999 - loss: 1.5172 - val_accuracy: 0.8282 - val_loss: 1.3656
# Epoch 56/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6740 - loss: 1.1352 - val_accuracy: 0.6252 - val_loss: 1.1889
# Epoch 57/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.6432 - loss: 1.1211 - val_accuracy: 0.7522 - val_loss: 0.9527
# Epoch 58/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7052 - loss: 0.8481 - val_accuracy: 0.7435 - val_loss: 0.8927
# Epoch 59/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7284 - loss: 0.9417 - val_accuracy: 0.8083 - val_loss: 0.8071
# Epoch 60/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7423 - loss: 0.7719 - val_accuracy: 0.8022 - val_loss: 0.9037
# Epoch 61/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7357 - loss: 0.7741 - val_accuracy: 0.8264 - val_loss: 0.8990
# Epoch 62/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7304 - loss: 0.8083 - val_accuracy: 0.8282 - val_loss: 0.8640
# Epoch 63/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7418 - loss: 0.7416 - val_accuracy: 0.8325 - val_loss: 0.8082
# Epoch 64/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7429 - loss: 0.7214 - val_accuracy: 0.7712 - val_loss: 0.8098
# Epoch 65/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7322 - loss: 0.7954 - val_accuracy: 0.8040 - val_loss: 0.7462
# Epoch 66/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7444 - loss: 0.7550 - val_accuracy: 0.8290 - val_loss: 0.7223
# Epoch 67/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7354 - loss: 0.7360 - val_accuracy: 0.8377 - val_loss: 0.7113
# Epoch 68/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7378 - loss: 0.8069 - val_accuracy: 0.8359 - val_loss: 0.7351
# Epoch 69/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7549 - loss: 0.7425 - val_accuracy: 0.8333 - val_loss: 0.7575
# Epoch 70/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7396 - loss: 0.7667 - val_accuracy: 0.8169 - val_loss: 0.7387
# Epoch 71/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7688 - loss: 0.7681 - val_accuracy: 0.8126 - val_loss: 0.7092
# Epoch 72/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7406 - loss: 0.7019 - val_accuracy: 0.8342 - val_loss: 0.6976
# Epoch 73/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7668 - loss: 0.6643 - val_accuracy: 0.8385 - val_loss: 0.6873
# Epoch 74/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7737 - loss: 0.6482 - val_accuracy: 0.8325 - val_loss: 0.6918
# Epoch 75/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7557 - loss: 0.7490 - val_accuracy: 0.8238 - val_loss: 0.7091
# Epoch 76/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7415 - loss: 0.7692 - val_accuracy: 0.8066 - val_loss: 0.6907
# Epoch 77/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7479 - loss: 0.7354 - val_accuracy: 0.8359 - val_loss: 0.6844
# Epoch 78/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7814 - loss: 0.6693 - val_accuracy: 0.8394 - val_loss: 0.6764
# Epoch 79/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7946 - loss: 0.6502 - val_accuracy: 0.8428 - val_loss: 0.6640
# Epoch 80/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7862 - loss: 0.6041 - val_accuracy: 0.8428 - val_loss: 0.6606
# Epoch 81/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7676 - loss: 0.6639 - val_accuracy: 0.8385 - val_loss: 0.6604
# Epoch 82/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7771 - loss: 0.6376 - val_accuracy: 0.8238 - val_loss: 0.6643
# Epoch 83/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8038 - loss: 0.6531 - val_accuracy: 0.8411 - val_loss: 0.6400
# Epoch 84/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7798 - loss: 0.7021 - val_accuracy: 0.8187 - val_loss: 0.6976
# Epoch 85/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7564 - loss: 0.7132 - val_accuracy: 0.8351 - val_loss: 0.6863
# Epoch 86/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6751 - loss: 0.8892 - val_accuracy: 0.7642 - val_loss: 0.6956
# Epoch 87/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7633 - loss: 0.6691 - val_accuracy: 0.7504 - val_loss: 0.6868
# Epoch 88/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7550 - loss: 0.6980 - val_accuracy: 0.8135 - val_loss: 0.6557
# Epoch 89/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7604 - loss: 0.6828 - val_accuracy: 0.8083 - val_loss: 0.6772
# Epoch 90/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7878 - loss: 0.6564 - val_accuracy: 0.7962 - val_loss: 0.6718
# Epoch 91/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7755 - loss: 0.6730 - val_accuracy: 0.8109 - val_loss: 0.6682
# Epoch 92/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7836 - loss: 0.6035 - val_accuracy: 0.8463 - val_loss: 0.6496
# Epoch 93/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7743 - loss: 0.6717 - val_accuracy: 0.8454 - val_loss: 0.6392
# Epoch 94/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7832 - loss: 0.6475 - val_accuracy: 0.8152 - val_loss: 0.6818
# Epoch 95/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7640 - loss: 0.6775 - val_accuracy: 0.8420 - val_loss: 0.6394
# Epoch 96/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7634 - loss: 0.6525 - val_accuracy: 0.8480 - val_loss: 0.6248
# Epoch 97/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7800 - loss: 0.6862 - val_accuracy: 0.8454 - val_loss: 0.6613
# Epoch 98/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7861 - loss: 0.6705 - val_accuracy: 0.7988 - val_loss: 0.6891
# Epoch 99/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7735 - loss: 0.6746 - val_accuracy: 0.8411 - val_loss: 0.6373
# Epoch 100/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7462 - loss: 0.7202 - val_accuracy: 0.8368 - val_loss: 0.6511
# Epoch 101/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7566 - loss: 0.7294 - val_accuracy: 0.8472 - val_loss: 0.6707
# Epoch 102/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7730 - loss: 0.6748 - val_accuracy: 0.8420 - val_loss: 0.6437
# Epoch 103/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7863 - loss: 0.6545 - val_accuracy: 0.8402 - val_loss: 0.6579
# Epoch 104/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7551 - loss: 0.7891 - val_accuracy: 0.8463 - val_loss: 0.6632
# Epoch 105/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8032 - loss: 0.5973 - val_accuracy: 0.8411 - val_loss: 0.6620
# Epoch 106/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7966 - loss: 0.6129 - val_accuracy: 0.8428 - val_loss: 0.6566
# Epoch 107/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8041 - loss: 0.6258 - val_accuracy: 0.8152 - val_loss: 0.6421
# Epoch 108/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7848 - loss: 0.6718 - val_accuracy: 0.8074 - val_loss: 0.6400
# Epoch 109/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7864 - loss: 0.6072 - val_accuracy: 0.8083 - val_loss: 0.6600
# Epoch 110/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7903 - loss: 0.6393 - val_accuracy: 0.8446 - val_loss: 0.6236
# Epoch 111/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8176 - loss: 0.5848 - val_accuracy: 0.8368 - val_loss: 0.6203
# Epoch 112/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7880 - loss: 0.6671 - val_accuracy: 0.8463 - val_loss: 0.7383
# Epoch 113/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7732 - loss: 0.6347 - val_accuracy: 0.8411 - val_loss: 0.6705
# Epoch 114/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8005 - loss: 0.6214 - val_accuracy: 0.8247 - val_loss: 0.6280
# Epoch 115/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7905 - loss: 0.6472 - val_accuracy: 0.8368 - val_loss: 0.6398
# Epoch 116/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7951 - loss: 0.6469 - val_accuracy: 0.8437 - val_loss: 0.6324
# Epoch 117/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7890 - loss: 0.6646 - val_accuracy: 0.8385 - val_loss: 0.6248
# Epoch 118/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7828 - loss: 0.6574 - val_accuracy: 0.8273 - val_loss: 0.6281
# Epoch 119/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7947 - loss: 0.5873 - val_accuracy: 0.8394 - val_loss: 0.6164
# Epoch 120/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8184 - loss: 0.5651 - val_accuracy: 0.8100 - val_loss: 0.6364
# Epoch 121/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8009 - loss: 0.5989 - val_accuracy: 0.8394 - val_loss: 0.6189
# Epoch 122/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7958 - loss: 0.6068 - val_accuracy: 0.8480 - val_loss: 0.6338
# Epoch 123/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8048 - loss: 0.5909 - val_accuracy: 0.8446 - val_loss: 0.6504
# Epoch 124/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8328 - loss: 0.5276 - val_accuracy: 0.8256 - val_loss: 0.7051
# Epoch 125/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8036 - loss: 0.7412 - val_accuracy: 0.8394 - val_loss: 0.6230
# Epoch 126/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7762 - loss: 0.6219 - val_accuracy: 0.8420 - val_loss: 0.6041
# Epoch 127/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7952 - loss: 0.6133 - val_accuracy: 0.8428 - val_loss: 0.6179
# Epoch 128/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7973 - loss: 0.6025 - val_accuracy: 0.8161 - val_loss: 0.6245
# Epoch 129/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8004 - loss: 0.5991 - val_accuracy: 0.8325 - val_loss: 0.6226
# Epoch 130/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7909 - loss: 0.6287 - val_accuracy: 0.8454 - val_loss: 0.6051
# Epoch 131/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7888 - loss: 0.6161 - val_accuracy: 0.8523 - val_loss: 0.5899
# Epoch 132/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8137 - loss: 0.5508 - val_accuracy: 0.8394 - val_loss: 0.5964
# Epoch 133/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7991 - loss: 0.5736 - val_accuracy: 0.8532 - val_loss: 0.5974
# Epoch 134/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8097 - loss: 0.6011 - val_accuracy: 0.8472 - val_loss: 0.5906
# Epoch 135/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8199 - loss: 0.5304 - val_accuracy: 0.8454 - val_loss: 0.5980
# Epoch 136/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8217 - loss: 0.5548 - val_accuracy: 0.8437 - val_loss: 0.6013
# Epoch 137/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8183 - loss: 0.5292 - val_accuracy: 0.8411 - val_loss: 0.5898
# Epoch 138/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8003 - loss: 0.5767 - val_accuracy: 0.8402 - val_loss: 0.6407
# Epoch 139/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8183 - loss: 0.5599 - val_accuracy: 0.8480 - val_loss: 0.5909
# Epoch 140/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8252 - loss: 0.5306 - val_accuracy: 0.8420 - val_loss: 0.5905
# Epoch 141/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8382 - loss: 0.5131 - val_accuracy: 0.8109 - val_loss: 0.6088
# Epoch 142/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8289 - loss: 0.5307 - val_accuracy: 0.8506 - val_loss: 0.5984
# Epoch 143/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8143 - loss: 0.5669 - val_accuracy: 0.8489 - val_loss: 0.6118
# Epoch 144/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8259 - loss: 0.5188 - val_accuracy: 0.8238 - val_loss: 0.5906
# Epoch 145/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8200 - loss: 0.5379 - val_accuracy: 0.8437 - val_loss: 0.6256
# Epoch 146/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7975 - loss: 0.6212 - val_accuracy: 0.8463 - val_loss: 0.5828
# Epoch 147/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7998 - loss: 0.5855 - val_accuracy: 0.8446 - val_loss: 0.6063
# Epoch 148/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8146 - loss: 0.5564 - val_accuracy: 0.8290 - val_loss: 0.5993
# Epoch 149/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8103 - loss: 0.5843 - val_accuracy: 0.8489 - val_loss: 0.5882
# Epoch 150/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8284 - loss: 0.5798 - val_accuracy: 0.8333 - val_loss: 0.6298
# Epoch 151/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8213 - loss: 0.5484 - val_accuracy: 0.8264 - val_loss: 0.6208
# Epoch 152/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8094 - loss: 0.5316 - val_accuracy: 0.8472 - val_loss: 0.6264
# Epoch 153/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8083 - loss: 0.5956 - val_accuracy: 0.8238 - val_loss: 0.5962
# Epoch 154/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8170 - loss: 0.5556 - val_accuracy: 0.8264 - val_loss: 0.5964
# Epoch 155/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7632 - loss: 0.6412 - val_accuracy: 0.8342 - val_loss: 0.6480
# Epoch 156/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7425 - loss: 0.7366 - val_accuracy: 0.8420 - val_loss: 0.5997
# Epoch 157/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7694 - loss: 0.6853 - val_accuracy: 0.7867 - val_loss: 0.6540
# Epoch 158/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7963 - loss: 0.5862 - val_accuracy: 0.8420 - val_loss: 0.5860
# Epoch 159/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.8114 - loss: 0.5428 - val_accuracy: 0.8480 - val_loss: 0.6114
# Epoch 160/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8363 - loss: 0.4973 - val_accuracy: 0.8377 - val_loss: 0.5880
# Epoch 161/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7997 - loss: 0.5624 - val_accuracy: 0.8342 - val_loss: 0.5959
# Epoch 162/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8440 - loss: 0.4820 - val_accuracy: 0.8428 - val_loss: 0.5910
# Epoch 163/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8255 - loss: 0.5636 - val_accuracy: 0.8523 - val_loss: 0.5977
# Epoch 164/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8246 - loss: 0.5100 - val_accuracy: 0.8307 - val_loss: 0.5923
# Epoch 165/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8405 - loss: 0.5102 - val_accuracy: 0.8463 - val_loss: 0.5811
# Epoch 166/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8063 - loss: 0.6037 - val_accuracy: 0.8247 - val_loss: 0.6147
# Epoch 167/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8049 - loss: 0.6031 - val_accuracy: 0.8454 - val_loss: 0.6075
# Epoch 168/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7840 - loss: 0.6377 - val_accuracy: 0.8325 - val_loss: 0.6010
# Epoch 169/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8290 - loss: 0.5231 - val_accuracy: 0.8472 - val_loss: 0.5920
# Epoch 170/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8523 - loss: 0.4569 - val_accuracy: 0.8472 - val_loss: 0.5787
# Epoch 171/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8347 - loss: 0.5040 - val_accuracy: 0.8178 - val_loss: 0.5982
# Epoch 172/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8218 - loss: 0.5183 - val_accuracy: 0.8489 - val_loss: 0.5798
# Epoch 173/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8293 - loss: 0.5183 - val_accuracy: 0.8515 - val_loss: 0.5662
# Epoch 174/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8425 - loss: 0.4933 - val_accuracy: 0.8316 - val_loss: 0.5826
# Epoch 175/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8270 - loss: 0.5203 - val_accuracy: 0.8480 - val_loss: 0.5761
# Epoch 176/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8369 - loss: 0.5123 - val_accuracy: 0.8472 - val_loss: 0.5971
# Epoch 177/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8315 - loss: 0.5166 - val_accuracy: 0.8454 - val_loss: 0.5950
# Epoch 178/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8348 - loss: 0.5244 - val_accuracy: 0.8446 - val_loss: 0.5704
# Epoch 179/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8229 - loss: 0.5427 - val_accuracy: 0.8385 - val_loss: 0.5960
# Epoch 180/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8203 - loss: 0.5622 - val_accuracy: 0.8480 - val_loss: 0.5720
# Epoch 181/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8349 - loss: 0.4894 - val_accuracy: 0.8480 - val_loss: 0.5759
# Epoch 182/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8422 - loss: 0.4825 - val_accuracy: 0.8480 - val_loss: 0.5809
# Epoch 183/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8267 - loss: 0.5361 - val_accuracy: 0.8497 - val_loss: 0.5795
# Epoch 184/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8429 - loss: 0.4872 - val_accuracy: 0.8256 - val_loss: 0.5737
# Epoch 185/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8500 - loss: 0.4652 - val_accuracy: 0.8463 - val_loss: 0.5558
# Epoch 186/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8485 - loss: 0.5044 - val_accuracy: 0.8454 - val_loss: 0.5978
# Epoch 187/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8244 - loss: 0.5238 - val_accuracy: 0.8497 - val_loss: 0.5864
# Epoch 188/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8213 - loss: 0.5451 - val_accuracy: 0.8420 - val_loss: 0.6315
# Epoch 189/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8352 - loss: 0.4996 - val_accuracy: 0.8299 - val_loss: 0.5976
# Epoch 190/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8467 - loss: 0.5054 - val_accuracy: 0.8178 - val_loss: 0.5897
# Epoch 191/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8545 - loss: 0.4428 - val_accuracy: 0.8532 - val_loss: 0.5804
# Epoch 192/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8473 - loss: 0.5147 - val_accuracy: 0.8506 - val_loss: 0.5861
# Epoch 193/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8471 - loss: 0.4376 - val_accuracy: 0.8316 - val_loss: 0.5677
# Epoch 194/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8331 - loss: 0.4875 - val_accuracy: 0.8506 - val_loss: 0.5632
# Epoch 195/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8490 - loss: 0.4467 - val_accuracy: 0.8480 - val_loss: 0.5734
# Epoch 196/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8392 - loss: 0.5117 - val_accuracy: 0.8351 - val_loss: 0.5627
# Epoch 197/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8465 - loss: 0.4667 - val_accuracy: 0.8472 - val_loss: 0.5706
# Epoch 198/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8609 - loss: 0.4186 - val_accuracy: 0.8333 - val_loss: 0.5861
# Epoch 199/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8241 - loss: 0.5119 - val_accuracy: 0.8351 - val_loss: 0.5915
# Epoch 200/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8402 - loss: 0.4706 - val_accuracy: 0.8446 - val_loss: 0.5904
# Epoch 201/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8339 - loss: 0.4766 - val_accuracy: 0.8463 - val_loss: 0.5768
# Epoch 202/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8330 - loss: 0.4942 - val_accuracy: 0.8454 - val_loss: 0.5992
# Epoch 203/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8493 - loss: 0.4447 - val_accuracy: 0.8437 - val_loss: 0.5752
# Epoch 204/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8584 - loss: 0.4523 - val_accuracy: 0.8472 - val_loss: 0.5743
# Epoch 205/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8655 - loss: 0.3951 - val_accuracy: 0.8342 - val_loss: 0.5881
# Epoch 206/3500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8566 - loss: 0.4171 - val_accuracy: 0.8394 - val_loss: 0.5919

# %%
n_epochs = len(history.history['loss'])

print(f"The model was trained for {n_epochs} epochs.")

# Evaluate the model on the train set  
test_loss, test_acc = model.evaluate(X_train, Y_train,verbose=2)
print(f'\nTest accuracy on training data: {test_acc} \n \n')

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test, verbose=2)
print(f'\nTest accuracy on test data: {test_acc}\n \n')

# Evaluate the model on the all data
test_loss, test_acc = model.evaluate(X_dict, Y, verbose=2)
print(f'\nTest accuracy on all data: {test_acc}\n \n')
# Out:
# The model was trained for 206 epochs.
# 121/121 - 1s - 8ms/step - accuracy: 0.8889 - loss: 0.3793
#
# Test accuracy on training data: 0.8888601064682007
#
#
# 31/31 - 0s - 9ms/step - accuracy: 0.8425 - loss: 0.5573
#
# Test accuracy on test data: 0.8424870371818542
#
#
# 151/151 - 1s - 8ms/step - accuracy: 0.8796 - loss: 0.4111
#
# Test accuracy on all data: 0.8795855045318604

# %%
import matplotlib.pyplot as plt
plt.plot([i for i in range(n_epochs)], history.history['accuracy'],label='Train')
plt.plot([i for i in range(n_epochs)], history.history['val_accuracy'],label='Val')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot([i for i in range(n_epochs)], history.history['loss'],label='Test')
plt.plot([i for i in range(n_epochs)], history.history['val_loss'],label='val')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

test_prediction = model.predict(X_test)
test_predicted_label = np.argmax(test_prediction, axis=1)
test_actual_label = np.argmax(Y_test, axis = 1)
conf_m = confusion_matrix(test_actual_label, test_predicted_label)

conf_m_show = ConfusionMatrixDisplay(confusion_matrix = conf_m)
conf_m_show.plot(include_values=True, cmap='Blues',ax = None, xticks_rotation= 'horizontal')
plt.show()
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
# saving the model   
model.save('/kaggle/working/m05-04-1.keras')

model.save('/kaggle/working/m05-04-1.h5')

# %%
# %cd /kaggle/working
from IPython.display import FileLink
FileLink('m05-04-1.keras')
# Out:
# /kaggle/working
# /kaggle/working/m05-04-1.keras

# %%
# %cd /kaggle/working
from IPython.display import FileLink
FileLink('m05-04-1.h5')
# Out:
# /kaggle/working
# /kaggle/working/m05-04-1.h5

# %%
import random

n = len(X_test['1'])
print(n)
# Generate a random integer
num = random.randint(1, n-1)
print(num)
x = {}
for key in X_dict.keys():
    arr = X_test[key][num]
#     print(arr.shape)
    arr = arr.reshape(1,arr.shape[0],arr.shape[-1])
#     print(arr.shape)
    x[key] = arr
y = Y_test[num]

print(type(x))
# print(x)

# Assuming my_model is your model and my_test_input_dict is your test input dictionary
y_pred = model.predict(x, verbose =2)

print(y_pred[0])
y_pred_arr = np.array([1 if i == max(y_pred[0]) else 0 for i in y_pred[0]])
print(y_pred_arr)
print(y)
print(event_types)
# Out:
# 965
# 525
# <class 'dict'>
# 1/1 - 0s - 36ms/step
# [0.9069561  0.00738734 0.00114878 0.08450789]
# [1 0 0 0]
# [1 0 0 0]
# {1: 'GRB', 2: 'TGF', 3: 'SGR', 4: 'SFLARE'}

# %%
from keras.models import load_model
import h5py

# Load the model
lmodel = load_model(r'/kaggle/working/m05-04-1.keras')

# Verify the model's architecture
lmodel.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ 0.001 (InputLayer)  │ (None, 60000, 1)  │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 0.005 (InputLayer)  │ (None, 12000, 1)  │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 0.01 (InputLayer)   │ (None, 6000, 1)   │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 0.1 (InputLayer)    │ (None, 600, 1)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 0.5 (InputLayer)    │ (None, 120, 1)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 1 (InputLayer)      │ (None, 60, 1)     │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 5 (InputLayer)      │ (None, 5, 1)      │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60000, 1)  │          4 │ 0.001[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12000, 1)  │          4 │ 0.005[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6000, 1)   │          4 │ 0.01[0][0]        │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 600, 1)    │          4 │ 0.1[0][0]         │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 1)    │          4 │ 0.5[0][0]         │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 1)     │          4 │ 1[0][0]           │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 1)      │          4 │ 5[0][0]           │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_22 (Conv1D)  │ (None, 8567, 64)  │      2,112 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_23 (Conv1D)  │ (None, 1710, 64)  │      2,112 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_24 (Conv1D)  │ (None, 1194, 64)  │      2,112 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_25 (Conv1D)  │ (None, 190, 64)   │      2,112 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_26 (Conv1D)  │ (None, 30, 64)    │      2,112 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_27 (Conv1D)  │ (None, 45, 32)    │        544 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_28 (Conv1D)  │ (None, 4, 4)      │         12 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_46          │ (None, 8567, 64)  │          0 │ conv1d_22[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_48          │ (None, 1710, 64)  │          0 │ conv1d_23[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_50          │ (None, 1194, 64)  │          0 │ conv1d_24[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_52          │ (None, 190, 64)   │          0 │ conv1d_25[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_54          │ (None, 30, 64)    │          0 │ conv1d_26[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_56          │ (None, 45, 32)    │          0 │ conv1d_27[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_58          │ (None, 4, 4)      │          0 │ conv1d_28[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_24          │ (None, 548288)    │          0 │ dropout_46[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_25          │ (None, 109440)    │          0 │ dropout_48[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_26          │ (None, 76416)     │          0 │ dropout_50[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_27          │ (None, 12160)     │          0 │ dropout_52[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_28          │ (None, 1920)      │          0 │ dropout_54[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_29          │ (None, 1440)      │          0 │ dropout_56[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_30          │ (None, 16)        │          0 │ dropout_58[0][0]  │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 64)        │ 35,090,496 │ flatten_24[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_25 (Dense)    │ (None, 64)        │  7,004,224 │ flatten_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_26 (Dense)    │ (None, 64)        │  4,890,688 │ flatten_26[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_27 (Dense)    │ (None, 64)        │    778,304 │ flatten_27[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_28 (Dense)    │ (None, 64)        │    122,944 │ flatten_28[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_29 (Dense)    │ (None, 64)        │     92,224 │ flatten_29[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 64)        │      1,088 │ flatten_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_47          │ (None, 64)        │          0 │ dense_24[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_49          │ (None, 64)        │          0 │ dense_25[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_51          │ (None, 64)        │          0 │ dense_26[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_53          │ (None, 64)        │          0 │ dense_27[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_55          │ (None, 64)        │          0 │ dense_28[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_57          │ (None, 64)        │          0 │ dense_29[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_59          │ (None, 64)        │          0 │ dense_30[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 448)       │          0 │ dropout_47[0][0], │
# │ (Concatenate)       │                   │            │ dropout_49[0][0], │
# │                     │                   │            │ dropout_51[0][0], │
# │                     │                   │            │ dropout_53[0][0], │
# │                     │                   │            │ dropout_55[0][0], │
# │                     │                   │            │ dropout_57[0][0], │
# │                     │                   │            │ dropout_59[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 7, 64, 1)  │          0 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 1, 58, 64) │      3,200 │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_31          │ (None, 3712)      │          0 │ conv2d_3[0][0]    │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_60          │ (None, 3712)      │          0 │ flatten_31[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 4)         │     14,852 │ dropout_60[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 96,018,316 (366.28 MB)
#  Trainable params: 48,009,150 (183.14 MB)
#  Non-trainable params: 14 (56.00 B)
#  Optimizer params: 48,009,152 (183.14 MB)

# %%
def model_conf(model,X,Y,conf_threshold = 0.7):
    conf_right = []
    conf_wrong = []
    if isinstance(X, dict):
        for n in range(len(Y)):
            x = {}
            for key in X.keys():
                arr = X[key][n]
                arr = arr.reshape(1,arr.shape[0],arr.shape[-1])
                x[key] = arr
            y = Y[n].tolist()

            y_pred = model.predict(x, verbose = 0).tolist()[0]
            
            # Find the index of the max value without using max() and index()
            max_value = y_pred[0]  # Assume the first element is the maximum
            max_index = 0

            for i, value in enumerate(y_pred):
                if value > max_value:
                    max_value = value
                    max_index = i

            if y.index(max(y)) == max_index and max_value > conf_threshold:
                conf_right.append(max_value)
            else:
                conf_wrong.append(max_value)
#             print(y)
#             print(y_pred)
#             print(max_value)
#             print(max(y))
            
    else:
        print('need dict')
    return len(conf_right)/(len(conf_right) + len(conf_wrong)), conf_right, conf_wrong

a,r,w = model_conf(model,X_test,Y_test)

print(a)
print('average conf when right',sum(r)/len(r))
print('average conf when wrong',sum(w)/len(w))
# Out:
# 0.7233160621761658
# average conf when right 0.9304951591614666
# average conf when wrong 0.6404390386427833

# %%
print(a)
print('average conf when right',sum(r)/len(r))
print('average conf when wrong',sum(w)/len(w))
# Out:
# 0.6466321243523316
# average conf when right 0.9513185050051945
# average conf when wrong 0.6652788776806023
