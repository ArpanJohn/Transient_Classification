# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        
        #print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
#   Cell In[10], line 18
#     # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
#                                                                                                                  ^
# SyntaxError: incomplete input

# %%
import numpy as np
import os
import glob
import matplotlib.pyplot as plt


# importing data
# Read the 2D array back from the text file

dir_path = "/kaggle/input/dp-5-30-2/d_big(-5_30)"
print(dir_path)
#print("Files in the directory:")
#print(os.listdir(dir_path))

data_needed = {'GRB': 800, 'TGF': 800, 'SGR': 400, 'SFLARE': 800}

event_types = {1:'GRB',2:'TGF',3:'SGR',4:'SFLARE'}
event_counter = {'GRB':0,'TGF':0,'SGR':0,'SFLARE':0}
# Replace 'your_search_string' with the string you are looking for in file names
search_string = 'bn'
search_pattern = os.path.join(dir_path, f'*{search_string}*')
#print(search_pattern)
matching_files = glob.glob(search_pattern)
#print(matching_files)

X_data = []
Y_data = []

for file in matching_files:
    event_type, event_name = os.path.basename(file).split('_')
    if (event_type== "DISTPAR"):
        continue
        
    if event_counter[event_type] < data_needed[event_type]:
        loaded_data = np.loadtxt(file, dtype=np.int16, delimiter='\t').astype(np.int16)
        X_data.append(loaded_data)
    
        y = [0,0,0,0]
        for key,value in event_types.items():
            if value in file.split('\\')[-1]:
                #print(value, file)
                y[key-1] = 1
                Y_data.append(y)
                event_counter[value] += 1
                break
 
    if all(count >= 400 for count in event_counter.values()):
        break
            
print(event_counter)  
X_data = np.array(X_data)
Y_data = np.array(Y_data)
print(X_data.shape)
print(Y_data.shape)
# Out:
# /kaggle/input/dp-5-30-2/d_big(-5_30)
# /tmp/ipykernel_34/1223904279.py:35: DeprecationWarning: loadtxt(): Parsing an integer via a float is deprecated.  To avoid this warning, you can:
#     * make sure the original data is stored as integers.
#     * use the `converters=` keyword argument.  If you only use
#       NumPy 1.23 or later, `converters=float` will normally work.
#     * Use `np.loadtxt(...).astype(np.int64)` parsing the file as
#       floating point and then convert it.  (On all NumPy versions.)
#   (Deprecated NumPy 1.23)
#   loaded_data = np.loadtxt(file, dtype=np.int16, delimiter='\t').astype(np.int16)
# {'GRB': 800, 'TGF': 800, 'SGR': 400, 'SFLARE': 800}
# (2800, 45955)
# (2800, 4)

# %%
import imblearn
from imblearn.over_sampling import SMOTE

oversample = SMOTE()

X_balanced, Y_balanced = oversample.fit_resample(X_data, Y_data)
print(X_balanced.shape)
print(Y_balanced.shape)
print(X_data.shape)
print(Y_data.shape)
# Out:
# (3200, 45955)
# (3200, 4)
# (2800, 45955)
# (2800, 4)

# %%
from sklearn.model_selection import train_test_split
print("X_balanced shape : ",X_balanced.shape)
print("Y_balanced_shape : ",Y_balanced.shape)
X_train, X_val, Y_train, Y_val = train_test_split(X_balanced, Y_balanced, test_size = 0.25,stratify=Y_balanced, random_state=42)
print("X_train shape",X_train.shape)
print("X_test shape",X_val.shape)
print("Y_train shape",Y_train.shape)
print("Y_test shape",Y_val.shape)
print(X_data.shape)
# Out:
# X_balanced shape :  (3200, 45955)
# Y_balanced_shape :  (3200, 4)
# X_train shape (2400, 45955)
# X_test shape (800, 45955)
# Y_train shape (2400, 4)
# Y_test shape (800, 4)
# (2800, 45955)

# %%
import tensorflow as tf
from keras import layers, models,regularizers
from keras.callbacks import EarlyStopping

tf.random.set_seed(42)
# Build the CNN model
model = models.Sequential()
model.add(layers.Conv1D(64, 4, activation='relu', input_shape=(X_train.shape[1:])+tuple([1]),kernel_regularizer=regularizers.l2(0.01)))
model.add(layers.MaxPooling1D((5)))
model.add(layers.Conv1D(32,1, activation='relu',kernel_regularizer=regularizers.l2(0.02)))
model.add(layers.MaxPooling1D((5)))
model.add(layers.Dropout(0.4))
model.add(layers.Conv1D(16,1, activation='relu',kernel_regularizer=regularizers.l2(0.02)))
model.add(layers.MaxPooling1D((5)))
model.add(layers.Dropout(0.4))


model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(layers.Dense(4, activation='softmax',kernel_regularizer=regularizers.l2(0.01)))
model.summary()
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Define the EarlyStopping callback
#early_stopping = EarlyStopping(monitor='val_loss', patience=20)

epoch = 90
# Train the model
history = model.fit(X_train, Y_train, epochs=epoch, batch_size=64, validation_split=0.2)#,callbacks=[early_stopping])

# Evaluate the model on the test set
train_loss, train_acc = model.evaluate(X_train, Y_train)
print(f'\n accuracy on training data: {train_acc} \n \n')

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_val, Y_val, verbose=2)
print(f'accuracy on test data: {test_acc}')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_6 (Conv1D)               │ (None, 45952, 64)      │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 9190, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 9190, 32)       │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 1838, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1838, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 1838, 16)       │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 367, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 367, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 5872)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │       375,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 389,332 (1.49 MB)
#  Trainable params: 389,332 (1.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 17s 373ms/step - accuracy: 0.2563 - loss: 6.3171 - val_accuracy: 0.6396 - val_loss: 4.6988
# Epoch 2/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.4576 - loss: 4.5410 - val_accuracy: 0.5708 - val_loss: 4.0893
# Epoch 3/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.5620 - loss: 3.9147 - val_accuracy: 0.5396 - val_loss: 3.6750
# Epoch 4/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.6013 - loss: 3.5303 - val_accuracy: 0.5917 - val_loss: 3.2951
# Epoch 5/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.6393 - loss: 3.2321 - val_accuracy: 0.6104 - val_loss: 3.0991
# Epoch 6/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.6309 - loss: 3.0421 - val_accuracy: 0.6625 - val_loss: 2.9059
# Epoch 7/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.6789 - loss: 2.8517 - val_accuracy: 0.6854 - val_loss: 2.8157
# Epoch 8/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.6417 - loss: 2.7838 - val_accuracy: 0.7208 - val_loss: 2.7320
# Epoch 9/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.6651 - loss: 2.6407 - val_accuracy: 0.6938 - val_loss: 2.5029
# Epoch 10/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.6950 - loss: 2.5083 - val_accuracy: 0.6792 - val_loss: 2.4122
# Epoch 11/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.6958 - loss: 2.3962 - val_accuracy: 0.7417 - val_loss: 2.3127
# Epoch 12/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.6915 - loss: 2.3668 - val_accuracy: 0.6583 - val_loss: 2.5274
# Epoch 13/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.6647 - loss: 2.4010 - val_accuracy: 0.7458 - val_loss: 2.2348
# Epoch 14/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.6933 - loss: 2.2457 - val_accuracy: 0.7104 - val_loss: 2.0769
# Epoch 15/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.7196 - loss: 2.1185 - val_accuracy: 0.7229 - val_loss: 2.0623
# Epoch 16/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.7329 - loss: 2.0440 - val_accuracy: 0.7292 - val_loss: 1.9893
# Epoch 17/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.7208 - loss: 2.0287 - val_accuracy: 0.7167 - val_loss: 2.0342
# Epoch 18/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.6973 - loss: 1.9900 - val_accuracy: 0.7354 - val_loss: 1.9403
# Epoch 19/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.7061 - loss: 1.9446 - val_accuracy: 0.6583 - val_loss: 2.0629
# Epoch 20/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.6983 - loss: 1.9512 - val_accuracy: 0.7063 - val_loss: 1.8469
# Epoch 21/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.7419 - loss: 1.8491 - val_accuracy: 0.7042 - val_loss: 1.7790
# Epoch 22/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.6935 - loss: 1.8352 - val_accuracy: 0.6938 - val_loss: 1.7449
# Epoch 23/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.7225 - loss: 1.7725 - val_accuracy: 0.7333 - val_loss: 1.6697
# Epoch 24/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.7190 - loss: 1.7609 - val_accuracy: 0.7312 - val_loss: 1.6874
# Epoch 25/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.7450 - loss: 1.6720 - val_accuracy: 0.7333 - val_loss: 1.5960
# Epoch 26/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.7230 - loss: 1.6973 - val_accuracy: 0.7229 - val_loss: 1.6891
# Epoch 27/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7366 - loss: 1.6220 - val_accuracy: 0.7563 - val_loss: 1.5568
# Epoch 28/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.
90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8037 - loss: 0.9964 - val_accuracy: 0.8271 - val_loss: 0.9999
# Epoch 64/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7872 - loss: 1.0422 - val_accuracy: 0.8271 - val_loss: 1.0004
# Epoch 65/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7873 - loss: 1.0160 - val_accuracy: 0.8375 - val_loss: 0.9561
# Epoch 66/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7867 - loss: 0.9922 - val_accuracy: 0.8438 - val_loss: 0.9237
# Epoch 67/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8001 - loss: 0.9957 - val_accuracy: 0.8396 - val_loss: 0.9015
# Epoch 68/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7852 - loss: 1.0009 - val_accuracy: 0.7750 - val_loss: 0.9680
# Epoch 69/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8074 - loss: 0.9642 - val_accuracy: 0.7875 - val_loss: 0.9566
# Epoch 70/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8149 - loss: 0.9402 - val_accuracy: 0.8313 - val_loss: 0.9113
# Epoch 71/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8101 - loss: 0.9395 - val_accuracy: 0.7937 - val_loss: 0.9387
# Epoch 72/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7955 - loss: 0.9405 - val_accuracy: 0.8354 - val_loss: 0.9016
# Epoch 73/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7996 - loss: 0.9434 - val_accuracy: 0.7792 - val_loss: 0.9393
# Epoch 74/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8129 - loss: 0.9039 - val_accuracy: 0.8125 - val_loss: 0.9988
# Epoch 75/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7665 - loss: 1.0418 - val_accuracy: 0.7792 - val_loss: 0.9675
# Epoch 76/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7998 - loss: 0.9590 - val_accuracy: 0.8354 - val_loss: 0.9207
# Epoch 77/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7836 - loss: 0.9850 - val_accuracy: 0.7729 - val_loss: 0.9542
# Epoch 78/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.8114 - loss: 0.9023 - val_accuracy: 0.8313 - val_loss: 0.9016
# Epoch 79/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7999 - loss: 0.9441 - val_accuracy: 0.8042 - val_loss: 0.9144
# Epoch 80/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8001 - loss: 0.9202 - val_accuracy: 0.8271 - val_loss: 0.8765
# Epoch 81/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.7949 - loss: 0.9151 - val_accuracy: 0.8396 - val_loss: 0.8627
# Epoch 82/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8033 - loss: 0.9049 - val_accuracy: 0.8104 - val_loss: 0.8781
# Epoch 83/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8145 - loss: 0.8723 - val_accuracy: 0.8250 - val_loss: 0.8572
# Epoch 84/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8153 - loss: 0.8585 - val_accuracy: 0.8354 - val_loss: 0.8529
# Epoch 85/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8073 - loss: 0.8909 - val_accuracy: 0.7437 - val_loss: 0.9586
# Epoch 86/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8139 - loss: 0.8599 - val_accuracy: 0.8417 - val_loss: 0.8626
# Epoch 87/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8199 - loss: 0.8689 - val_accuracy: 0.8188 - val_loss: 0.9081
# Epoch 88/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8048 - loss: 0.8678 - val_accuracy: 0.7875 - val_loss: 0.8820
# Epoch 89/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8324 - loss: 0.8302 - val_accuracy: 0.8062 - val_loss: 0.8700
# Epoch 90/90
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.8330 - loss: 0.8140 - val_accuracy: 0.8354 - val_loss: 0.8569
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8684 - loss: 0.7536
#
#  accuracy on training data: 0.8545833230018616
#
#
# 25/25 - 0s - 5ms/step - accuracy: 0.8263 - loss: 0.8774
# accuracy on test data: 0.8262500166893005

# %%
# Evaluate the model on the test set
train_loss, train_acc = model.evaluate(X_train, Y_train)
print(f'\n accuracy on training data: {train_acc} \n \n')

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_val, Y_val, verbose=2)
print(f'accuracy on test data: {test_acc}')
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8684 - loss: 0.7536
#
#  accuracy on training data: 0.8545833230018616
#
#
# 25/25 - 0s - 5ms/step - accuracy: 0.8263 - loss: 0.8774
# accuracy on test data: 0.8262500166893005

# %%
import matplotlib.pyplot as plt
plt.plot([i for i in range(epoch)], history.history['accuracy'],label='Train')
plt.plot([i for i in range(epoch)], history.history['val_accuracy'],label='Val')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
## import matplotlib.pyplot as plt
plt.plot([i for i in range(epoch)], history.history['loss'],label='Train')
plt.plot([i for i in range(epoch)], history.history['val_loss'],label='Val')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

test_prediction = model.predict(X_val)
test_predicted_label = np.argmax(test_prediction, axis=1)
test_actual_label = np.argmax(Y_val, axis = 1)
conf_m = confusion_matrix(test_actual_label, test_predicted_label)

conf_m_show = ConfusionMatrixDisplay(confusion_matrix = conf_m)
conf_m_show.plot(include_values=True, cmap='Blues',ax = None, xticks_rotation= 'horizontal')
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
import json

# Save the model
model.save('/kaggle/working/saved_(-5_30)_2m_balned_.h5')

# Save additional details using JSON
details = {
    'dataset': '(-5_30)_2m',
    'data' : [800,800,800,800],
    'architecture': 'CNN_balanced',
    'parameters': {
        'epochs': 90,
        'batch_size': 64,
        'learning_rate': 0.001,
        '2_Drop_out':[0.4,'after_sec',0.3,'after_third'],
        'l2regularizer' : ['0.01_input','0.02_conv','0.01_dense'],
        'kernel_size':4,
        'filters':{
            'input_layer':64,
            'first_conv':32,
            'second_conv':16
        },
        'v_acc': 0.8162500262260437,
        't_acc': 0.8441666960716248,
        'Dense_layers': [64,64,64,32,4]     
    }
}

with open('/kaggle/working/model_detail_m_balned_7.json', 'w') as f:
    json.dump(details, f)

# %%
from keras.models import load_model

lmodel_2 = load_model(r"/kaggle/working/saved_(-5_30)_2m_balned_.h5")
lmodel_2.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_6 (Conv1D)               │ (None, 45952, 64)      │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 9190, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 9190, 32)       │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 1838, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1838, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 1838, 16)       │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 367, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 367, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 5872)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │       375,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 389,334 (1.49 MB)
#  Trainable params: 389,332 (1.49 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
def model_conf_u(model,X,Y,conf_threshold = 0.6):
    conf=[]
    a = 0
    w = 0
    uncert = 0

    for n in range(len(Y)):
        
        x = X[n].reshape(1, X[n].shape[0], 1)
        y = Y[n].tolist()

        y_pred = model.predict(x, verbose = 0).tolist()[0]

        max_value = y_pred[0]
        max_index = 0

        for i, value in enumerate(y_pred):
            if value > max_value:
                max_value = value
                max_index = i

        if max_value > conf_threshold:
            if y.index(max(y)) == max_index:
                conf.append(max_value)
                a = a+1
            else:
                w = w+1
        else:
            uncert = uncert+1
    
    print('confidently right', a/len(Y))
    print('confidently wrong', w/len(Y))
    print('uncertain', uncert/len(Y))

model_conf_u(lmodel_2,X_balanced,Y_balanced,0.6)
# Out:
# confidently right 0.7121875
# confidently wrong 0.0521875
# uncertain 0.235625

# %%
def model_conf(model, X, Y, conf_threshold=0.6):
    conf_right = []
    conf_wrong = []

    for n in range(len(Y)):
        x = X[n].reshape(1, X[n].shape[0], 1)  # Reshape each data point to (1, 45955, 1)

        y = Y[n].tolist()
        y_pred = model.predict(x, verbose=0).tolist()[0]
        
        max_value = y_pred[0]
        max_index = 0

        for i, value in enumerate(y_pred):
            if value > max_value:
                max_value = value
                max_index = i

        if y.index(max(y)) == max_index and max_value > conf_threshold:
            conf_right.append(max_value)
        else:
            conf_wrong.append(max_value)            

    return len(conf_right) / (len(conf_right) + len(conf_wrong)), conf_right, conf_wrong

a,r,w = model_conf(lmodel_2,X_balanced,Y_balanced,0.6)

print(a)
print('average conf when right',sum(r)/len(r))
print('average conf when wrong',sum(w)/len(w))
# Out:
# 0.7121875
# average conf when right 0.8866651445797212
# average conf when wrong 0.5417683278893026
